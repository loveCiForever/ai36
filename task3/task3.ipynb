# %% [markdown]
# # Libraries

# %%
import random
import numpy as np
import time
import matplotlib.pyplot as plt

# %% [markdown]
# # Constants, params

# %%
BOARD_SIZE = 16
POPULATION_SIZE = 1000
MUTATION_RATE = 0.1
MAX_GENERATION = 10000

# %% [markdown]
# # ChessBoard class (Visualize the Chessboard in 2D array)

# %%
class ChessBoard:
  """ A class to represent a chessboard in 2D array.

  Attributes:
    board_size (int): The size of the chessboard.
    board (numpy.ndarray): A 2D array representing the chessboard.

  Every cell of the initial chessboard will be filled by a dot "."
  And the Queen will be perform by a "Q" after process the `state`.

  """

  def __init__ (self, board_size:int):
    self.board_size = board_size
    self.board = np.full((self.board_size, self.board_size), ".", dtype='<U1')

  def place_queen(self, state):
    self.board.fill(".")
    for col, row in enumerate(state):
      if row >= 0 and row < self.board_size:
        self.board[row, col] = "Q"

  def print_board(self):
    print()
    for row in self.board:
      print(" ".join(row))

  def visualize_chessboard(self):
    plt.figure(figsize=(self.board_size, self.board_size))

    color_map = np.where(self.board == "Q", 1, 0)

    cmap = plt.cm.colors.ListedColormap(['lightblue', 'orange'])
    plt.imshow(color_map, cmap=cmap, interpolation='nearest')

    plt.xticks(ticks=np.arange(self.board_size), labels=np.arange(self.board_size))
    plt.yticks(ticks=np.arange(self.board_size), labels=np.arange(self.board_size))

    for row in range(self.board_size):
      for col in range(self.board_size):
        if self.board[row, col] == "Q":
            plt.text(col, row, 'Q', ha='center', va='center', fontsize=20, color='black', zorder=10)

    # Show main and anti diagonal grid
    # for start in range(self.board_size):
    #     plt.plot([start, self.board_size - 1], [0, self.board_size - 1 - start], color='blue', linewidth=1, zorder=5)
    #     plt.plot([start, 0], [self.board_size - 1, self.board_size - 1 - start], color='blue', linewidth=1, zorder=5)
    #     plt.plot([start, 0], [0, start], color='blue', linewidth=1, zorder=5)
    #     plt.plot([start, self.board_size - 1], [self.board_size - 1, start], color='blue', linewidth=1, zorder=5)

    queens_positions = [(row, col) for row in range(self.board_size) for col in range(self.board_size) if self.board[row, col] == "Q"]

    attacking_rows = set()
    attacking_cols = set()

    for i in range(len(queens_positions)):
      for j in range(i + 1, len(queens_positions)):
        row1, col1 = queens_positions[i]
        row2, col2 = queens_positions[j]

        if abs(row1 - row2) == abs(col1 - col2):
          if row1 < row2:
            plt.plot([col1, col2], [row1, row2], color='red', linewidth=4, zorder=5)
          else:
            plt.plot([col1, col2], [row1, row2], color='blue', linewidth=4, zorder=5)

        if row1 == row2:
          attacking_rows.add(row1)
        if col1 == col2:
          attacking_cols.add(col1)

    for row in attacking_rows:
      plt.axhline(y=row, color='red', linewidth=4, linestyle='--', zorder=4)

    for col in attacking_cols:
      plt.axvline(x=col, color='red', linewidth=4, linestyle='--', zorder=4)

    plt.title("Chessboard Visualization")
    plt.gca().invert_yaxis()
    plt.show()

if __name__ == "__main__":
    board_size = 8
    chessboard = ChessBoard(board_size)
    example_state = [0, 7, 4, 2, 5, 3, 1, 7]
    chessboard.place_queen(example_state)
    chessboard.visualize_chessboard()

# %% [markdown]
# # State class (Visualize the Chess board in 1D array)
#
# ## For example:
# - We have a 4x4 Chess board below (Index of colum and row both start from 0):
#     ```
#     3 . . . Q
#     2 Q . . .
#     1 . Q . .
#     0 . . Q .
#     \ 0 1 2 3
#     ```
# It will be visualized: `[2, 1, 0, 3]`
# - That means, `col[0]` have a Queen placed at `row[2]` -> `queen[0][2]` and so on ...

# %%
class State:
  """ A class to represent a state of a chessboard.

  Attributes:
    board_size (int): The size of the chessboard.
    state (list): A list of integers representing the row positions of queens.
    maximum_non_attacking_pairs (int): The maximum number of non-attacking pairs of queens.
    fitness_score (int): The fitness score of the state.
    selection_prob (float): The selection probability of the state.
    length (int): The length of the state
  """

  def __init__(self, board_size:int, random_state:bool):
    self.board_size = board_size
    self.state = []
    self.maximum_non_attacking_pairs = self.board_size * (self.board_size - 1) // 2
    self.selection_prob = None

    if random_state:
      self.state = [random.randint(0, self.board_size - 1) for _ in range(0, self.board_size)]
      self.fitness_score = self.calculate_fitness()
      self.length = self.get_state_length()

  def set_state(self, state):
    self.state = state
    self.fitness_score = self.calculate_fitness()
    self.length = self.get_state_length()

  def get_state(self):
    return self.state

  def set_selection_prob(self, selection_prob):
    self.selection_prob = selection_prob

  def get_selection_prob(self):
    return self.selection_prob

  def get_fitness(self):
    return self.fitness_score

  def calculate_fitness(self): # O(n)
    number_of_queen_in_each_column = [0] * (self.board_size)

    # For a chessboard size of N * N, there will be 2 * (2 * N - 1) diagonal from both side
    number_of_queen_in_main_diagonal = [0] * (2 * self.board_size - 1)  # From -(n - 1) to (n - 1)
    number_of_queen_in_anti_diagonal = [0] * (2 * self.board_size - 1)  # From 0 to (2n - 2)

    for row in range(self.board_size):
      col = self.state[row]
      number_of_queen_in_each_column[col] += 1
      number_of_queen_in_main_diagonal[row - col + (self.board_size - 1)] += 1
      number_of_queen_in_anti_diagonal[row + col] += 1

    attacking_pairs = 0

    for count in number_of_queen_in_each_column:
      if count > 1:
        attacking_pairs += count * (count - 1) // 2

    for count in number_of_queen_in_main_diagonal:
      if count > 1:
        attacking_pairs += count * (count - 1) // 2

    for count in number_of_queen_in_anti_diagonal:
      if count > 1:
        attacking_pairs += count

    return self.maximum_non_attacking_pairs - attacking_pairs

  def mutate_state(self, position: int, value: int):
    self.state[position - 1] = value
    self.fitness_score = self.calculate_fitness()

  def get_state_length(self):
    return __builtins__.len(self.state)

  def to_table(self, table_name:str):
    print(f"{table_name.upper()}")
    print(f"{'State':<65} {'Length':<15} {'Fitness Score':<15}")
    print("=" * 100)
    print(f"{str(self.get_state()):<67} {self.get_state_length(): <18} {self.get_fitness():<18}")

# %% [markdown]
# # Testing State class and ChessBoard class

# %%
if __name__ == "__main__":
  state_obj = State(board_size=BOARD_SIZE, random_state=False)
  state_obj.set_state([1, 4, 8, 14, 4, 10, 10, 6, 0, 0, 8, 8, 2, 15, 6, 1])
  state_obj.to_table("\nSolution")

  chess_board_obj = ChessBoard(board_size=16)
  chess_board_obj.place_queen(state_obj.get_state())
  # chess_board_obj.print_board()
  chess_board_obj.visualize_chessboard()
# Out:
# SOLUTION
# State                                                             Length          Fitness Score
# ====================================================================================================
# [1, 4, 8, 14, 4, 10, 10, 6, 0, 0, 8, 8, 2, 15, 6, 1]                16                 107

# %% [markdown]
# # GeneticAlgorithm class

# %%
class Population:
  def __init__(self, board_size:int, population_size:int, mutation_rate:float, none_population: bool):
    self.board_size = board_size
    self.population_size = population_size
    self.mutation_rate = mutation_rate
    if none_population:
      self.population = []
    else:
      self.population = self.generate_population()

    self.max_fitness = self.calculate_max_fitness()
    self.selection_prob = self.set_selection_prob_for_all_state()

  def add_new_state_to_population(self, state):
    self.population.append(state)

  def generate_population(self):
    return [State(self.board_size, random_state=True) for _ in range(self.population_size)]

  def print_population(self):
    for state in self.population:
      print(f"{str(state.get_state()):<70} {state.get_fitness():<18}")

  def get_population(self):
    return self.population

  def get_population_length(self):
    return __builtins__.len(self.population)

  def set_selection_prob_for_all_state(self):
    total_fitness = sum(state.get_fitness() for state in self.population)
    selection_probs = []
    for state in self.population:
      selection_prob = state.get_fitness() / total_fitness
      state.set_selection_prob(selection_prob)
      selection_probs.append(selection_prob)

    return selection_probs

  def evaluate_population(self):
    self.population.sort(key=lambda state: state.get_fitness(), reverse=True)
    self.population = self.population[:-1]

  def make_couples(self):
    if (len(self.population) % 2) != 0:
      self.population.append(self.population[0])

  def population_pop(self, pos:int):
    self.population.pop(pos)

  def crossover_two_state(self, parent1, parent2):
    crossover_start_point = random.randint(1, self.board_size - 3)
    crossover_end_point = random.randint(crossover_start_point + 1, self.board_size - 1)

    allele1 = parent1.get_state()[crossover_start_point:crossover_end_point]
    allele3 = parent2.get_state()[crossover_start_point:crossover_end_point]

    allele2 = parent2.get_state().copy()
    for num in allele1:
      for i in allele2:
        if num == i:
          allele2.remove(i)
          break

    allele2 = allele2

    allele4 = parent1.get_state().copy()
    for num in allele3:
      for i in allele4:
        if num == i:
          allele4.remove(i)
          break

    allele4 = allele4

    tmp1 = __builtins__.len(allele1) + __builtins__.len(allele2)
    tmp2 = __builtins__.len(allele3) + __builtins__.len(allele4)

    if tmp1 == 16:
      child1 = allele2[:crossover_start_point] + allele1 + allele2[crossover_start_point:]
    else:
      child_end_point = -(abs(BOARD_SIZE - tmp1))
      child1 = allele2[:crossover_start_point] + allele1 + allele2[crossover_start_point:child_end_point]

    if tmp2 == 16:
      child2 = allele4[:crossover_start_point] + allele3 + allele4[crossover_start_point:]
    else:
      child_end_point = -(abs(BOARD_SIZE - tmp2))
      child2 = allele4[:crossover_start_point] + allele3 + allele4[crossover_start_point:child_end_point]

    child1_state = State(self.board_size, random_state=False)
    child1_state.set_state(child1)

    child2_state = State(self.board_size, random_state=False)
    child2_state.set_state(child2)

    return child1_state, child2_state

  def crossover_population(self):
    for i in range(0, len(self.population), 2):
      parent1 = self.population[i]
      parent2 = self.population[i + 1]
      child1, child2 = self.crossover_two_state(parent1, parent2)

      self.population[i] = child1
      self.population[i + 1] = child2

  def mutation(self):
    for state in self.population:
        if random.random() < self.mutation_rate:
            random_position = random.randint(0, self.board_size - 1)
            random_value = random.randint(0, self.board_size - 1)
            state.mutate_state(random_position, random_value)

  def calculate_max_fitness(self):
    max_fitness = 0
    for state in self.population:
      if state.get_fitness() > max_fitness:
        max_fitness = state.get_fitness()
    return max_fitness

  def get_state_max_fitness(self):
    for state in self.population:
      if state.get_fitness() == self.max_fitness:
        return state

  def get_max_fitness(self):
    self.max_fitness = self.calculate_max_fitness()
    return self.max_fitness

  def to_table(self, table_name:str):
    print(f"{table_name.upper()} (Length = {self.get_population_length()})")
    print("=" * 103)
    print(f"{'State':<65} {'Fitness Score':<15} {'Selection Probability' :<15}")
    print("=" * 103)
    for state in self.population:
      print(f"{str(state.get_state()):<70} {state.get_fitness():<17} {state.get_selection_prob():.4f}")

if __name__ == "__main__":
  start_time = time.time()
  current_generation = Population(board_size=BOARD_SIZE, population_size=POPULATION_SIZE, mutation_rate=MUTATION_RATE, none_population=False)
  current_generation.to_table("\nInitial Population")

  loop = 0

  def run(current_generation):
    global loop

    while loop < MAX_GENERATION:
      print(f"LOOP: {loop} / {MAX_GENERATION} ", end="")
      current_generation.evaluate_population()
      current_generation.set_selection_prob_for_all_state()
      # current_generation.to_table("\nAfter evaluation")
      current_generation.make_couples()
      current_generation.set_selection_prob_for_all_state()
      # current_generation.to_table("\nAfter make couple")
      current_generation.crossover_population()
      current_generation.set_selection_prob_for_all_state()
      # current_generation.to_table("\nAfter crossover")
      current_generation.mutation()
      current_generation.set_selection_prob_for_all_state()
      # current_generation.to_table("\nAfter mutation")

      print(f"--> Max fitness: {current_generation.get_max_fitness()}")

      if current_generation.get_max_fitness() == 120:
        print(f"\n🟢🟢🟢 SOLUTION FOUND at loop {loop} / {MAX_GENERATION}")
        solution = State(board_size=BOARD_SIZE, random_state=False)
        solution = current_generation.get_state_max_fitness()
        solution.to_table("\n")

        chess_board_obj = ChessBoard(board_size=BOARD_SIZE)
        chess_board_obj.place_queen(solution.get_state())
        # chess_board_obj.print_board()
        chess_board_obj.visualize_chessboard()

        return
      loop += 1

    print("🔴🔴🔴 No solution found after {loop} loop")

  run(current_generation=current_generation)

  end_time = time.time()
  elapsed_time = end_time - start_time
  print(f"\nTime taken to find the solution: {elapsed_time:.2f} seconds")
# Out:
# INITIAL POPULATION (Length = 1000)
# =======================================================================================================
# State                                                             Fitness Score   Selection Probability
# =======================================================================================================
# [10, 15, 7, 15, 11, 9, 7, 3, 7, 6, 13, 2, 2, 6, 10, 12]                102               0.0010
# [6, 3, 2, 8, 5, 13, 13, 11, 4, 5, 2, 10, 2, 4, 15, 4]                  100               0.0010
# [14, 1, 2, 5, 3, 14, 15, 12, 1, 8, 9, 0, 15, 4, 7, 12]                 101               0.0010
# [2, 6, 12, 0, 8, 3, 4, 4, 2, 7, 7, 0, 10, 8, 6, 1]                     99                0.0010
# [1, 8, 4, 3, 7, 1, 3, 8, 8, 7, 4, 4, 2, 9, 0, 2]                       95                0.0009
# [1, 0, 7, 8, 5, 7, 13, 12, 9, 11, 10, 10, 2, 5, 11, 3]                 98                0.0010
# [11, 8, 4, 7, 10, 0, 11, 4, 0, 5, 0, 14, 12, 0, 7, 1]                  105               0.0010
# [10, 11, 9, 11, 1, 3, 6, 5, 12, 4, 0, 5, 7, 3, 12, 1]                  101               0.0010
# [5, 10, 15, 9, 9, 13, 3, 3, 6, 13, 2, 14, 14, 6, 9, 10]                106               0.0011
# [0, 9, 6, 5, 9, 13, 8, 11, 4, 6, 14, 13, 15, 4, 6, 7]                  100               0.0010
# [5, 3, 2, 9, 13, 11, 7, 5, 4, 2, 8, 10, 13, 15, 5, 14]                 105               0.0010
# [5, 0, 1, 0, 9, 4, 14, 4, 13, 12, 12, 1, 3, 2, 15, 2]                  102               0.0010
# [9, 11, 6, 5, 6, 8, 14, 4, 6, 5, 3, 14, 10, 2, 3, 6]                   101               0.0010
# [6, 15, 5, 0, 4, 5, 15, 11, 9, 5, 5, 15, 7, 12, 8, 3]                  106               0.0011
# [8, 13, 14, 5, 3, 15, 10, 0, 5, 14, 1, 4, 0, 0, 12, 15]                104               0.0010
# [7, 13, 15, 8, 13, 9, 5, 11, 10, 1, 14, 0, 8, 4, 15, 13]               102               0.0010
# [12, 3, 0, 6, 0, 0, 8, 7, 8, 11, 9, 4, 11, 4, 13, 1]                   101               0.0010
# [15, 11, 11, 9, 11, 1, 0, 9, 2, 10, 4, 3, 10, 6, 9, 9]                 94                0.0009
# [12, 3, 10, 8, 5, 0, 15, 8, 12, 7, 1, 12, 13, 10, 12, 2]               99                0.0010
# [6, 1, 10, 1, 13, 0, 9, 5, 5, 11, 10, 3, 1, 1, 8, 10]                  99                0.0010
# [13, 0, 14, 2, 1, 7, 11, 11, 2, 4, 15, 11, 4, 12, 0, 7]                98                0.0010
# [2, 2, 1, 4, 9, 2, 5, 9, 5, 1, 12, 11, 3, 11, 11, 3]                   94                0.0009
# [4, 5, 0, 3, 13, 4, 2, 2, 10, 6, 5, 5, 2, 15, 12, 2]                   98                0.0010
# [14, 2, 7, 11, 4, 10, 15, 7, 7, 13, 12, 15, 10, 0, 1, 1]               101               0.0010
# [0, 1, 1, 7, 5, 6, 9, 6, 4, 5, 7, 13, 14, 13, 11, 2]                   103               0.0010
# [4, 7, 4, 1, 9, 14, 6, 5, 13, 15, 14, 14, 11, 14, 1, 13]               99                0.0010
# [0, 14, 6, 11, 6, 14, 2, 9, 12, 7, 4, 9, 12, 15, 8, 1]                 100               0.0010
# [13, 10, 0, 11, 6, 1, 10, 9, 6, 1, 0, 0, 7, 8, 2, 5]                   100               0.0010
# [2, 4, 12, 12, 10, 1, 8, 8, 9, 6, 3, 3, 14, 13, 14, 15]                100               0.0010
# [11, 4, 5, 3, 4, 12, 4, 7, 1, 8, 8, 7, 12, 15, 14, 0]                  96                0.0010
# [8, 9, 11, 4, 12, 8, 11, 15, 2, 1, 11, 11, 10, 1, 10, 7]               94                0.0009
# [1, 11, 15, 15, 13, 13, 10, 1, 4, 15, 8, 7, 2, 6, 5, 5]                102               0.0010
# [4, 3, 6, 1, 3, 10, 4, 1, 0, 4, 8, 2, 14, 15, 1, 7]                    95                0.0009
# [5, 11, 11, 2, 12, 1, 9, 8, 11, 0, 1, 15, 13, 10, 2, 11]               100               0.0010
# [9, 12, 4, 13, 15, 12, 3, 0, 0, 8, 12, 8, 9, 0, 2, 9]                  95                0.0009
# [4, 11, 14, 5, 11, 7, 3, 0, 8, 0, 14, 6, 5, 6, 13, 4]                  99                0.0010
# [7, 9, 8, 7, 4, 9, 14, 0, 6, 8, 2, 3, 13, 6, 8, 11]                    102               0.0010
# [5, 0, 2, 0, 8, 4, 10, 3, 15, 2, 4, 14, 1, 14, 14, 15]                 108               0.0011
# [9, 6, 10, 4, 7, 10, 11, 9, 15, 10, 2, 8, 15, 11, 4, 4]                99                0.0010
# [11, 7, 7, 5, 1, 6, 2, 11, 0, 8, 0, 8, 10, 12, 0, 9]                   106               0.0011
# [8, 5, 14, 15, 8, 3, 8, 14, 5, 5, 7, 12, 3, 15, 3, 0]                  97                0.0010
# [2, 12, 14, 1, 0, 7, 2, 12, 0, 0, 1, 3, 13, 15, 12, 13]                96                0.0010
# [3, 5, 0, 0, 1, 5, 15, 12, 1, 0, 3, 14, 7, 3, 4, 15]                   100               0.0010
# [2, 13, 4, 4, 1, 3, 7, 11, 15, 14, 8, 15, 6, 0, 4, 2]                  102               0.0010
# [0, 14, 5, 9, 11, 9, 7, 15, 13, 1, 3, 13, 10, 11, 9, 2]                106               0.0011
# [2, 15, 0, 5, 6, 10, 7, 6, 1, 6, 11, 3, 0, 1, 10, 12]                  100               0.0010
# [11, 4, 4, 6, 5, 11, 5, 0, 13, 4, 1, 13, 3, 12, 4, 6]                  97                0.0010
# [2, 13, 14, 7, 2, 12, 11, 11, 6, 13, 3, 5, 7, 8, 11, 10]               98                0.0010
# [1, 6, 12, 1, 8, 2, 8, 3, 4, 15, 8, 15, 12, 8, 2, 7]                   99                0.0010
# [13, 12, 7, 9, 11, 8, 10, 15, 8, 7, 15, 9, 8, 14, 1, 1]                100               0.0010
# [11, 12, 11, 0, 10, 11, 13, 6, 13, 6, 3, 15, 5, 15, 4, 13]             102               0.0010
# [5, 4, 8, 8, 11, 11, 1, 7, 0, 4, 14, 7, 6, 10, 9, 13]                  105               0.0010
# [8, 2, 11, 10, 3, 5, 15, 11, 2, 5, 13, 4, 8, 15, 6, 1]                 107               0.0011
# [0, 13, 2, 8, 12, 1, 14, 13, 14, 13, 3, 11, 6, 12, 5, 3]               102               0.0010
# [8, 2, 8, 2, 8, 7, 12, 2, 0, 10, 6, 11, 7, 0, 3, 11]                   101               0.0010
# [10, 11, 15, 12, 13, 2, 1, 1, 2, 0, 11, 15, 11, 11, 8, 9]              95                0.0009
# [1, 6, 14, 9, 1, 1, 4, 2, 9, 15, 2, 7, 5, 5, 2, 14]                    99                0.0010
# [5, 12, 15, 13, 3, 15, 2, 5, 15, 0, 7, 14, 4, 1, 0, 13]                106               0.0011
# [12, 4, 11, 11, 15, 6, 11, 15, 15, 9, 8, 8, 12, 1, 2, 8]               99                0.0010
# [12, 0, 13, 9, 15, 14, 11, 0, 7, 0, 12, 15, 11, 3, 8, 7]               100               0.0010
# [13, 6, 12, 10, 3, 9, 13, 9, 4, 8, 3, 4, 15, 8, 0, 11]                 103               0.0010
# [11, 0, 14, 4, 6, 10, 14, 4, 4, 3, 11, 13, 12, 8, 5, 3]                104               0.0010
# [5, 0, 4, 9, 2, 2, 0, 0, 11, 11, 15, 8, 12, 3, 10, 2]                  101               0.0010
# [0, 13, 9, 14, 11, 8, 14, 3, 11, 15, 9, 1, 7, 13, 6, 15]               105               0.0010
# [12, 8, 12, 14, 9, 8, 5, 3, 4, 15, 13, 13, 12, 15, 9, 5]               100               0.0010
# [9, 12, 9, 11, 5, 9, 5, 12, 11, 3, 12, 14, 0, 0, 3, 0]                 95                0.0009
# [0, 6, 0, 6, 3, 13, 11, 5, 11, 9, 11, 14, 1, 7, 3, 10]                 99                0.0010
# [13, 7, 0, 11, 13, 0, 9, 7, 9, 2, 14, 5, 1, 10, 13, 11]                107               0.0011
# [1, 8, 15, 11, 9, 0, 1, 3, 6, 0, 5, 9, 2, 10, 5, 0]                    102               0.0010
# [8, 12, 6, 11, 15, 3, 7, 11, 15, 7, 11, 12, 10, 3, 7, 15]              89                0.0009
# [6, 13, 15, 7, 10, 7, 15, 15, 9, 7, 2, 12, 3, 5, 0, 9]                 103               0.0010
# [1, 13, 9, 4, 5, 11, 11, 14, 12, 4, 9, 11, 0, 2, 7, 5]                 106               0.0011
# [5, 13, 6, 2, 12, 15, 5, 10, 3, 5, 10, 14, 15, 4, 9, 11]               99                0.0010
# [12, 11, 15, 7, 1, 0, 1, 14, 13, 15, 10, 5, 10, 8, 15, 1]              101               0.0010
# [0, 9, 7, 10, 13, 1, 0, 10, 6, 13, 9, 10, 15, 1, 2, 6]                 101               0.0010
# [5, 13, 10, 4, 7, 2, 10, 15, 1, 15, 12, 4, 14, 3, 6, 9]                106               0.0011
# [2, 10, 4, 10, 3, 14, 4, 5, 5, 2, 14, 13, 0, 4, 8, 7]                  98                0.0010
# [4, 15, 13, 5, 11, 3, 1, 10, 7, 4, 9, 12, 10, 14, 11, 10]              102               0.0010
# [1, 5, 10, 12, 9, 12, 3, 8, 6, 9, 3, 6, 14, 9, 9, 7]                   101               0.0010
# [3, 8, 8, 5, 8, 15, 14, 11, 15, 11, 15, 4, 13, 8, 13, 12]              99                0.0010
# [7, 12, 1, 13, 14, 12, 3, 7, 12, 3, 13, 15, 7, 13, 6, 13]              99                0.0010
# [2, 1, 9, 10, 7, 4, 9, 12, 10, 8, 7, 12, 10, 6, 4, 9]                  97                0.0010
# [1, 6, 9, 13, 12, 2, 13, 6, 5, 4, 8, 12, 15, 0, 9, 15]                 101               0.0010
# [8, 13, 15, 15, 3, 6, 6, 11, 14, 11, 4, 4, 13, 5, 13, 2]               103               0.0010
# [1, 5, 14, 7, 5, 7, 0, 2, 1, 11, 8, 8, 0, 13, 7, 5]                    98                0.0010
# [7, 3, 14, 4, 4, 14, 12, 1, 10, 7, 14, 12, 7, 10, 2, 8]                95                0.0009
# [10, 4, 3, 11, 5, 4, 0, 5, 10, 0, 7, 10, 3, 6, 0, 8]                   100               0.0010
# [6, 11, 13, 14, 1, 6, 6, 4, 13, 12, 14, 1, 9, 13, 12, 0]               94                0.0009
# [13, 5, 11, 7, 4, 3, 0, 13, 7, 14, 4, 4, 1, 5, 3, 0]                   99                0.0010
# [7, 4, 12, 4, 12, 2, 13, 11, 15, 1, 5, 1, 10, 3, 0, 5]                 103               0.0010
# [1, 5, 7, 7, 3, 13, 5, 12, 11, 9, 6, 1, 15, 9, 13, 4]                  101               0.0010
# [2, 2, 11, 8, 7, 2, 10, 0, 4, 12, 9, 11, 2, 3, 13, 7]                  101               0.0010
# [7, 6, 7, 8, 14, 0, 9, 13, 8, 9, 10, 3, 0, 2, 8, 10]                   98                0.0010
# [2, 1, 8, 13, 4, 3, 5, 9, 6, 15, 9, 8, 6, 3, 5, 15]                    97                0.0010
# [4, 2, 11, 15, 11, 4, 5, 3, 12, 9, 2, 15, 4, 13, 14, 4]                99                0.0010
# [5, 0, 15, 11, 7, 15, 0, 12, 6, 4, 7, 8, 1, 11, 0, 6]                  101               0.0010
# [6, 5, 5, 13, 2, 1, 2, 2, 10, 14, 4, 3, 7, 0, 11, 9]                   107               0.0011
# [5, 1, 0, 11, 5, 10, 3, 1, 7, 11, 12, 8, 6, 11, 8, 4]                  97                0.0010
# [14, 2, 4, 14, 8, 9, 15, 7, 5, 13, 2, 15, 5, 2, 4, 1]                  100               0.0010
# [7, 1, 8, 11, 7, 6, 3, 11, 9, 12, 11, 10, 2, 2, 3, 14]                 99                0.0010
# [5, 13, 14, 8, 2, 4, 8, 8, 9, 14, 9, 8, 9, 5, 7, 3]                    94                0.0009
# [12, 5, 12, 6, 8, 9, 10, 9, 1, 6, 11, 11, 12, 14, 0, 6]                93                0.0009
# [5, 2, 4, 12, 8, 5, 7, 2, 5, 7, 10, 1, 15, 4, 0, 8]                    107               0.0011
# [0, 7, 8, 6, 9, 10, 3, 12, 3, 14, 4, 3, 13, 12, 7, 6]                  99                0.0010
# [11, 4, 11, 1, 10, 9, 15, 6, 7, 13, 6, 1, 14, 8, 14, 14]               103               0.0010
# [14, 10, 5, 14, 9, 13, 14, 8, 9, 15, 9, 13, 1, 4, 2, 1]                101               0.0010
# [7, 14, 0, 2, 13, 10, 14, 5, 4, 0, 13, 0, 8, 9, 6, 11]                 101               0.0010
# [11, 11, 12, 0, 14, 7, 7, 7, 15, 4, 12, 12, 14, 2, 3, 6]               96                0.0010
# [15, 15, 0, 11, 14, 1, 10, 9, 5, 12, 10, 4, 12, 10, 11, 4]             104               0.0010
# [15, 9, 12, 5, 15, 9, 13, 2, 9, 1, 4, 8, 12, 11, 7, 15]                102               0.0010
# [4, 8, 11, 1, 4, 2, 12, 6, 11, 5, 5, 4, 11, 0, 14, 5]                  102               0.0010
# [0, 0, 5, 0, 8, 11, 6, 12, 5, 9, 7, 3, 15, 5, 8, 13]                   101               0.0010
# [5, 5, 6, 4, 6, 13, 15, 9, 9, 2, 4, 8, 6, 9, 9, 12]                    102               0.0010
# [4, 15, 7, 8, 3, 15, 8, 3, 12, 3, 8, 1, 1, 12, 10, 11]                 101               0.0010
# [7, 2, 8, 5, 0, 6, 8, 2, 0, 12, 9, 6, 14, 6, 13, 15]                   104               0.0010
# [7, 12, 4, 5, 5, 7, 2, 9, 6, 0, 2, 7, 3, 13, 10, 0]                    96                0.0010
# [13, 8, 11, 9, 0, 5, 14, 10, 7, 13, 9, 8, 12, 3, 2, 4]                 108               0.0011
# [14, 15, 6, 9, 12, 12, 5, 10, 11, 14, 2, 12, 8, 7, 7, 4]               101               0.0010
# [6, 8, 14, 4, 15, 7, 5, 1, 13, 9, 5, 4, 7, 2, 11, 13]                  110               0.0011
# [8, 14, 15, 5, 10, 9, 8, 2, 11, 11, 1, 12, 7, 6, 6, 4]                 101               0.0010
# [4, 12, 10, 13, 14, 0, 9, 15, 9, 11, 4, 13, 5, 1, 10, 8]               106               0.0011
# [14, 4, 5, 7, 13, 1, 12, 15, 5, 14, 7, 4, 14, 2, 10, 0]                106               0.0011
# [1, 0, 6, 15, 3, 15, 9, 6, 14, 11, 9, 1, 7, 4, 4, 9]                   98                0.0010
# [11, 3, 8, 0, 9, 15, 10, 1, 11, 14, 6, 10, 14, 3, 14, 4]               107               0.0011
# [0, 9, 11, 12, 5, 14, 3, 12, 14, 13, 9, 1, 6, 14, 0, 10]               103               0.0010
# [1, 3, 4, 7, 14, 11, 0, 8, 8, 7, 7, 3, 9, 4, 0, 0]                     97                0.0010
# [2, 15, 10, 14, 13, 12, 3, 13, 8, 14, 14, 0, 7, 15, 6, 10]             105               0.0010
# [10, 7, 4, 0, 11, 4, 12, 7, 11, 1, 4, 6, 14, 7, 5, 12]                 102               0.0010
# [8, 8, 12, 12, 3, 2, 7, 0, 6, 6, 4, 11, 0, 9, 12, 6]                   100               0.0010
# [1, 4, 1, 9, 15, 5, 11, 9, 1, 10, 13, 2, 12, 11, 13, 1]                101               0.0010
# [10, 2, 11, 14, 1, 6, 2, 13, 10, 9, 8, 15, 1, 0, 0, 13]                107               0.0011
# [9, 14, 4, 1, 4, 11, 14, 8, 3, 4, 7, 15, 1, 12, 13, 1]                 105               0.0010
# [3, 2, 6, 1, 9, 15, 9, 14, 3, 2, 10, 3, 0, 8, 10, 14]                  103               0.0010
# [8, 12, 4, 13, 15, 0, 6, 0, 11, 1, 12, 6, 6, 9, 8, 5]                  105               0.0010
# [8, 1, 9, 8, 0, 4, 3, 8, 1, 14, 8, 12, 2, 2, 11, 9]                    99                0.0010
# [9, 9, 2, 9, 7, 2, 3, 11, 8, 4, 12, 7, 11, 14, 4, 11]                  103               0.0010
# [9, 3, 10, 10, 3, 14, 1, 7, 9, 8, 8, 10, 15, 3, 5, 0]                  102               0.0010
# [11, 0, 9, 7, 8, 7, 11, 8, 3, 3, 4, 13, 14, 8, 0, 6]                   97                0.0010
# [10, 9, 4, 7, 2, 3, 14, 9, 2, 14, 13, 9, 10, 11, 0, 6]                 92                0.0009
# [3, 14, 0, 11, 7, 11, 4, 6, 14, 14, 9, 14, 10, 2, 4, 3]                97                0.0010
# [3, 0, 8, 0, 3, 14, 15, 5, 12, 4, 0, 6, 2, 1, 12, 15]                  103               0.0010
# [2, 6, 8, 1, 8, 11, 6, 1, 6, 1, 14, 14, 4, 5, 13, 12]                  98                0.0010
# [9, 13, 13, 4, 4, 9, 6, 2, 12, 4, 3, 4, 15, 5, 11, 14]                 100               0.0010
# [14, 4, 5, 15, 2, 4, 15, 2, 7, 14, 10, 3, 9, 12, 15, 13]               103               0.0010
# [10, 15, 10, 14, 13, 12, 12, 4, 9, 6, 4, 7, 13, 15, 3, 12]             102               0.0010
# [3, 13, 12, 9, 11, 5, 9, 0, 6, 6, 1, 15, 5, 2, 5, 13]                  103               0.0010
# [11, 9, 15, 2, 6, 0, 3, 1, 11, 13, 0, 1, 4, 12, 14, 9]                 108               0.0011
# [4, 14, 6, 5, 1, 12, 9, 0, 5, 10, 7, 14, 15, 10, 7, 14]                97                0.0010
# [12, 14, 11, 3, 7, 1, 13, 15, 7, 6, 7, 4, 3, 2, 10, 0]                 105               0.0010
# [12, 12, 15, 4, 7, 3, 12, 15, 14, 2, 7, 12, 8, 3, 5, 0]                103               0.0010
# [0, 5, 15, 11, 1, 6, 15, 6, 1, 13, 9, 1, 0, 10, 13, 6]                 102               0.0010
# [11, 3, 1, 7, 5, 1, 3, 11, 12, 9, 5, 7, 11, 10, 4, 5]                  94                0.0009
# [2, 14, 12, 1, 5, 5, 6, 11, 5, 6, 8, 10, 6, 14, 8, 11]                 101               0.0010
# [0, 15, 11, 1, 0, 1, 2, 1, 1, 0, 15, 14, 7, 5, 0, 10]                  94                0.0009
# [4, 0, 0, 6, 6, 11, 7, 14, 1, 7, 12, 0, 7, 8, 11, 12]                  101               0.0010
# [15, 8, 10, 9, 7, 13, 10, 11, 2, 7, 11, 15, 3, 9, 12, 7]               96                0.0010
# [1, 0, 6, 12, 15, 13, 7, 13, 11, 14, 0, 11, 10, 3, 6, 2]               106               0.0011
# [8, 8, 12, 11, 9, 0, 8, 7, 8, 3, 11, 1, 11, 11, 0, 0]                  96                0.0010
# [4, 7, 14, 14, 9, 0, 7, 10, 1, 11, 3, 15, 3, 8, 15, 4]                 106               0.0011
# [12, 13, 14, 13, 5, 13, 12, 8, 10, 12, 6, 11, 8, 7, 3, 3]              98                0.0010
# [1, 5, 4, 7, 10, 4, 8, 11, 10, 3, 13, 4, 6, 8, 1, 2]                   97                0.0010
# [10, 4, 15, 13, 4, 1, 9, 5, 1, 8, 6, 6, 10, 14, 11, 15]                105               0.0010
# [3, 10, 11, 9, 3, 11, 9, 6, 12, 5, 1, 1, 6, 11, 5, 5]                  96                0.0010
# [11, 7, 0, 7, 13, 15, 13, 3, 0, 15, 14, 15, 11, 9, 7, 5]               98                0.0010
# [4, 9, 8, 3, 8, 9, 11, 10, 5, 10, 1, 13, 12, 5, 14, 8]                 102               0.0010
# [13, 7, 15, 9, 8, 15, 4, 0, 8, 15, 14, 11, 4, 7, 11, 8]                96                0.0010
# [11, 1, 13, 11, 15, 5, 0, 7, 11, 13, 11, 13, 12, 9, 11, 2]             90                0.0009
# [15, 2, 15, 8, 5, 12, 2, 3, 10, 11, 1, 11, 11, 4, 4, 11]               98                0.0010
# [10, 2, 5, 9, 6, 2, 9, 11, 11, 8, 11, 2, 15, 15, 8, 11]                96                0.0010
# [0, 0, 14, 5, 0, 5, 8, 0, 2, 9, 10, 8, 12, 14, 9, 3]                   95                0.0009
# [7, 5, 13, 13, 5, 11, 4, 4, 9, 8, 7, 8, 1, 1, 6, 6]                    104               0.0010
# [13, 6, 4, 9, 14, 11, 14, 4, 8, 14, 13, 12, 8, 10, 11, 10]             97                0.0010
# [0, 4, 15, 0, 2, 3, 11, 7, 7, 4, 2, 10, 8, 6, 13, 7]                   106               0.0011
# [9, 6, 15, 0, 7, 6, 13, 6, 2, 14, 14, 0, 13, 6, 11, 0]                 99                0.0010
# [0, 7, 2, 5, 10, 5, 15, 10, 14, 7, 13, 14, 14, 11, 5, 1]               97                0.0010
# [9, 11, 12, 7, 12, 14, 3, 9, 15, 8, 8, 12, 2, 11, 12, 10]              98                0.0010
# [6, 13, 14, 14, 14, 11, 7, 11, 12, 10, 12, 11, 5, 14, 1, 15]           95                0.0009
# [12, 6, 1, 1, 9, 14, 4, 10, 6, 7, 1, 6, 13, 15, 9, 7]                  102               0.0010
# [11, 0, 7, 8, 2, 6, 2, 0, 9, 15, 14, 10, 12, 2, 8, 14]                 103               0.0010
# [4, 12, 15, 12, 14, 3, 4, 5, 9, 2, 4, 13, 7, 1, 3, 14]                 106               0.0011
# [11, 13, 5, 4, 15, 10, 14, 12, 12, 7, 2, 6, 15, 6, 7, 4]               103               0.0010
# [6, 10, 10, 3, 4, 1, 7, 0, 3, 13, 6, 0, 7, 12, 3, 4]                   98                0.0010
# [3, 10, 3, 3, 9, 8, 3, 5, 9, 1, 10, 12, 15, 8, 13, 10]                 97                0.0010
# [13, 6, 11, 6, 12, 8, 9, 5, 1, 10, 1, 14, 0, 9, 8, 9]                  98                0.0010
# [3, 11, 4, 9, 8, 1, 7, 9, 8, 4, 2, 13, 8, 4, 10, 15]                   94                0.0009
# [1, 7, 0, 10, 13, 4, 7, 10, 15, 7, 1, 5, 8, 8, 3, 3]                   103               0.0010
# [13, 4, 5, 8, 15, 3, 10, 6, 7, 11, 11, 2, 9, 10, 3, 0]                 107               0.0011
# [4, 6, 11, 8, 7, 15, 1, 14, 9, 5, 14, 1, 11, 11, 11, 11]               99                0.0010
# [2, 1, 0, 15, 1, 0, 4, 7, 5, 11, 1, 5, 10, 3, 15, 13]                  98                0.0010
# [14, 11, 4, 6, 10, 1, 8, 11, 5, 0, 15, 3, 14, 8, 4, 9]                 103               0.0010
# [12, 0, 9, 1, 7, 5, 6, 11, 1, 13, 5, 0, 14, 1, 6, 3]                   104               0.0010
# [13, 10, 2, 14, 1, 3, 9, 13, 2, 10, 4, 3, 13, 8, 15, 1]                107               0.0011
# [1, 5, 7, 9, 1, 9, 6, 7, 14, 11, 1, 12, 3, 2, 1, 11]                   99                0.0010
# [0, 11, 4, 10, 13, 6, 15, 4, 11, 14, 3, 8, 15, 15, 8, 15]              100               0.0010
# [1, 1, 10, 4, 7, 11, 13, 10, 1, 7, 3, 10, 13, 0, 8, 3]                 102               0.0010
# [11, 8, 15, 6, 14, 3, 2, 4, 6, 5, 8, 6, 10, 6, 13, 14]                 92                0.0009
# [13, 6, 5, 1, 7, 7, 9, 15, 11, 7, 4, 13, 6, 4, 0, 5]                   100               0.0010
# [5, 11, 9, 2, 0, 12, 12, 7, 10, 9, 1, 4, 9, 10, 0, 12]                 98                0.0010
# [2, 9, 3, 1, 0, 10, 7, 5, 5, 10, 10, 14, 6, 12, 2, 2]                  103               0.0010
# [4, 3, 10, 15, 8, 2, 2, 7, 0, 9, 4, 3, 4, 1, 14, 10]                   95                0.0009
# [8, 12, 14, 2, 15, 5, 4, 2, 6, 8, 7, 5, 4, 5, 7, 11]                   102               0.0010
# [12, 12, 2, 8, 1, 0, 12, 0, 7, 8, 1, 6, 2, 10, 2, 10]                  99                0.0010
# [10, 4, 9, 13, 11, 9, 5, 14, 1, 4, 1, 5, 9, 1, 3, 2]                   97                0.0010
# [8, 15, 15, 4, 0, 15, 7, 1, 4, 10, 9, 3, 0, 13, 2, 5]                  100               0.0010
# [0, 10, 15, 2, 15, 2, 13, 3, 9, 2, 5, 1, 14, 4, 3, 6]                  106               0.0011
# [10, 11, 1, 14, 4, 6, 15, 9, 6, 15, 9, 3, 3, 1, 10, 4]                 104               0.0010
# [1, 8, 6, 5, 11, 0, 2, 11, 8, 3, 9, 11, 5, 5, 10, 11]                  99                0.0010
# [5, 8, 1, 12, 5, 1, 2, 3, 6, 8, 5, 8, 7, 3, 15, 3]                     98                0.0010
# [5, 6, 7, 11, 0, 3, 0, 3, 12, 12, 14, 7, 12, 9, 8, 11]                 94                0.0009
# [12, 6, 15, 11, 5, 5, 3, 6, 10, 10, 2, 1, 10, 9, 11, 12]               102               0.0010
# [11, 1, 13, 15, 9, 6, 11, 10, 7, 8, 1, 11, 3, 12, 15, 6]               95                0.0009
# [4, 3, 15, 11, 7, 1, 4, 10, 3, 2, 8, 3, 9, 13, 5, 2]                   103               0.0010
# [12, 11, 0, 6, 15, 13, 0, 7, 7, 4, 14, 11, 13, 14, 10, 8]              109               0.0011
# [7, 12, 0, 2, 3, 12, 13, 9, 4, 15, 14, 0, 6, 5, 7, 8]                  106               0.0011
# [1, 6, 14, 9, 5, 7, 15, 1, 5, 1, 2, 9, 5, 10, 14, 15]                  104               0.0010
# [0, 11, 6, 4, 10, 12, 4, 2, 2, 5, 11, 14, 14, 15, 4, 9]                107               0.0011
# [15, 8, 12, 5, 0, 7, 1, 5, 14, 10, 5, 12, 11, 2, 0, 6]                 103               0.0010
# [13, 3, 1, 4, 14, 14, 9, 6, 5, 15, 10, 7, 0, 5, 12, 6]                 110               0.0011
# [1, 14, 12, 1, 8, 9, 15, 14, 12, 12, 3, 0, 13, 0, 5, 1]                101               0.0010
# [11, 0, 4, 0, 7, 1, 7, 9, 4, 6, 0, 1, 10, 4, 4, 3]                     95                0.0009
# [12, 10, 6, 7, 11, 12, 3, 15, 0, 0, 4, 1, 12, 5, 9, 5]                 105               0.0010
# [9, 7, 3, 0, 11, 3, 6, 8, 1, 1, 3, 13, 13, 1, 10, 1]                   98                0.0010
# [5, 4, 10, 11, 8, 15, 4, 13, 2, 6, 9, 13, 7, 6, 11, 4]                 100               0.0010
# [15, 2, 9, 7, 10, 14, 15, 2, 12, 11, 5, 12, 3, 12, 8, 6]               103               0.0010
# [12, 3, 14, 1, 1, 1, 14, 3, 9, 5, 8, 12, 5, 8, 12, 5]                  94                0.0009
# [15, 0, 4, 2, 2, 1, 15, 14, 15, 1, 12, 7, 1, 1, 2, 5]                  98                0.0010
# [4, 9, 1, 11, 4, 8, 5, 10, 7, 12, 2, 3, 8, 9, 9, 2]                    101               0.0010
# [5, 15, 0, 0, 7, 13, 6, 5, 7, 0, 12, 0, 10, 8, 13, 3]                  99                0.0010
# [3, 5, 7, 4, 9, 9, 12, 4, 1, 15, 9, 6, 13, 15, 0, 8]                   106               0.0011
# [6, 3, 3, 10, 14, 15, 5, 7, 3, 1, 2, 10, 12, 5, 5, 12]                 102               0.0010
# [7, 7, 13, 6, 4, 13, 7, 1, 3, 13, 12, 7, 10, 4, 6, 11]                 100               0.0010
# [4, 11, 12, 6, 9, 8, 4, 6, 14, 12, 6, 11, 0, 9, 9, 10]                 97                0.0010
# [1, 2, 13, 0, 6, 3, 11, 9, 1, 4, 6, 0, 15, 7, 9, 3]                    108               0.0011
# [0, 14, 3, 3, 0, 7, 15, 8, 3, 11, 10, 11, 2, 14, 15, 9]                96                0.0010
# [11, 14, 2, 0, 14, 15, 9, 8, 2, 0, 4, 0, 7, 10, 4, 7]                  103               0.0010
# [3, 11, 12, 11, 0, 0, 15, 9, 3, 5, 3, 10, 9, 8, 14, 11]                98                0.0010
# [10, 1, 14, 6, 12, 1, 13, 3, 8, 8, 10, 3, 3, 6, 3, 13]                 96                0.0010
# [1, 6, 6, 11, 1, 6, 13, 7, 15, 3, 7, 0, 5, 5, 15, 14]                  100               0.0010
# [7, 15, 13, 3, 8, 12, 10, 11, 15, 4, 12, 5, 5, 9, 4, 7]                99                0.0010
# [3, 15, 9, 5, 8, 6, 7, 5, 6, 12, 5, 4, 7, 4, 12, 9]                    100               0.0010
# [1, 11, 14, 6, 11, 15, 3, 12, 7, 13, 15, 6, 2, 11, 8, 12]              105               0.0010
# [15, 9, 13, 8, 12, 15, 0, 12, 14, 6, 2, 11, 9, 13, 3, 13]              105               0.0010
# [2, 12, 3, 13, 0, 5, 14, 3, 8, 8, 2, 4, 8, 8, 3, 15]                   96                0.0010
# [11, 5, 8, 13, 13, 7, 11, 1, 12, 8, 6, 14, 10, 7, 9, 1]                105               0.0010
# [3, 7, 13, 6, 4, 11, 6, 13, 4, 0, 13, 6, 8, 6, 11, 5]                  92                0.0009
# [0, 4, 6, 6, 10, 8, 11, 5, 6, 0, 15, 14, 2, 15, 14, 3]                 96                0.0010
# [9, 14, 6, 4, 6, 5, 4, 4, 3, 14, 14, 14, 14, 10, 13, 7]                96                0.0010
# [10, 14, 5, 2, 4, 13, 6, 1, 2, 13, 8, 9, 11, 11, 6, 15]                100               0.0010
# [12, 13, 12, 0, 15, 2, 12, 12, 7, 5, 12, 8, 10, 15, 1, 13]             90                0.0009
# [3, 10, 6, 6, 10, 2, 12, 1, 10, 14, 4, 3, 8, 2, 8, 12]                 99                0.0010
# [14, 9, 14, 14, 8, 1, 10, 2, 3, 9, 13, 5, 2, 11, 3, 7]                 105               0.0010
# [9, 10, 9, 9, 12, 9, 1, 0, 3, 11, 8, 12, 4, 11, 3, 5]                  99                0.0010
# [8, 1, 3, 9, 5, 14, 2, 13, 0, 14, 6, 8, 0, 6, 14, 12]                  101               0.0010
# [3, 10, 11, 10, 11, 2, 4, 5, 0, 9, 4, 14, 11, 11, 2, 3]                99                0.0010
# [14, 8, 11, 10, 0, 9, 10, 10, 15, 1, 8, 7, 10, 2, 8, 5]                97                0.0010
# [5, 5, 13, 15, 15, 3, 2, 8, 14, 8, 5, 5, 2, 7, 1, 9]                   101               0.0010
# [7, 12, 12, 11, 10, 13, 6, 10, 11, 0, 13, 9, 10, 15, 7, 2]             103               0.0010
# [10, 10, 11, 12, 2, 13, 14, 12, 1, 2, 15, 1, 11, 15, 14, 4]            101               0.0010
# [14, 10, 0, 0, 2, 14, 14, 6, 3, 3, 6, 4, 15, 7, 1, 15]                 104               0.0010
# [2, 10, 8, 13, 1, 15, 2, 4, 11, 9, 11, 14, 3, 6, 2, 5]                 105               0.0010
# [2, 0, 14, 5, 3, 2, 14, 8, 12, 8, 12, 4, 3, 10, 7, 13]                 100               0.0010
# [14, 3, 4, 12, 2, 9, 9, 4, 2, 15, 14, 9, 7, 15, 6, 13]                 94                0.0009
# [11, 10, 14, 2, 11, 4, 7, 3, 4, 4, 6, 12, 0, 2, 4, 9]                  97                0.0010
# [15, 1, 7, 11, 6, 11, 1, 5, 15, 13, 0, 5, 15, 2, 11, 1]                103               0.0010
# [11, 6, 7, 13, 9, 9, 2, 12, 2, 1, 1, 10, 8, 11, 14, 11]                101               0.0010
# [15, 15, 6, 0, 2, 2, 12, 4, 4, 8, 3, 6, 5, 4, 4, 15]                   99                0.0010
# [8, 5, 8, 5, 1, 4, 2, 8, 9, 11, 13, 1, 7, 15, 14, 3]                   106               0.0011
# [1, 10, 12, 14, 15, 14, 9, 4, 0, 3, 6, 7, 8, 8, 7, 8]                  103               0.0010
# [11, 14, 1, 4, 13, 9, 15, 9, 15, 6, 0, 6, 1, 0, 2, 10]                 105               0.0010
# [10, 12, 10, 8, 11, 12, 0, 14, 14, 13, 10, 15, 2, 11, 7, 4]            106               0.0011
# [7, 2, 4, 12, 5, 11, 0, 8, 13, 1, 11, 15, 6, 9, 3, 4]                  104               0.0010
# [8, 10, 15, 12, 14, 15, 8, 15, 7, 0, 0, 4, 1, 14, 14, 9]               106               0.0011
# [4, 1, 0, 10, 2, 10, 7, 14, 2, 12, 6, 9, 0, 3, 5, 1]                   103               0.0010
# [12, 3, 0, 5, 4, 6, 0, 10, 11, 9, 6, 15, 8, 9, 9, 2]                   105               0.0010
# [10, 1, 5, 5, 0, 12, 15, 11, 13, 1, 8, 5, 9, 7, 6, 5]                  101               0.0010
# [10, 10, 7, 8, 9, 0, 10, 14, 8, 4, 11, 14, 1, 6, 14, 10]               92                0.0009
# [0, 8, 10, 3, 8, 5, 3, 0, 0, 11, 0, 3, 11, 9, 11, 7]                   92                0.0009
# [10, 4, 6, 13, 0, 12, 10, 14, 5, 4, 10, 12, 3, 11, 13, 12]             102               0.0010
# [12, 9, 11, 12, 7, 6, 7, 4, 7, 15, 15, 10, 0, 0, 11, 0]                94                0.0009
# [2, 8, 4, 7, 10, 0, 0, 15, 3, 10, 11, 14, 2, 11, 6, 12]                109               0.0011
# [3, 11, 10, 4, 5, 0, 0, 5, 14, 4, 9, 0, 12, 4, 10, 6]                  104               0.0010
# [5, 8, 6, 7, 11, 11, 5, 5, 13, 2, 4, 15, 1, 13, 0, 13]                 101               0.0010
# [2, 13, 7, 10, 7, 9, 13, 4, 0, 5, 8, 3, 9, 4, 14, 2]                   104               0.0010
# [12, 14, 13, 8, 7, 12, 4, 0, 3, 9, 9, 13, 12, 0, 1, 0]                 101               0.0010
# [13, 2, 4, 15, 10, 15, 7, 8, 12, 2, 15, 13, 12, 6, 0, 3]               99                0.0010
# [4, 8, 12, 13, 11, 8, 5, 13, 6, 6, 9, 8, 2, 14, 8, 1]                  99                0.0010
# [4, 15, 3, 12, 11, 10, 14, 2, 7, 4, 9, 13, 13, 1, 5, 6]                108               0.0011
# [13, 3, 7, 1, 9, 8, 9, 9, 7, 13, 2, 9, 10, 5, 11, 13]                  91                0.0009
# [0, 13, 1, 0, 8, 15, 4, 9, 3, 14, 2, 11, 11, 0, 1, 3]                  105               0.0010
# [7, 7, 13, 6, 5, 3, 14, 5, 8, 8, 5, 15, 8, 14, 5, 7]                   97                0.0010
# [6, 7, 14, 4, 12, 11, 6, 7, 6, 7, 11, 1, 6, 15, 13, 5]                 95                0.0009
# [11, 4, 13, 6, 11, 11, 11, 12, 12, 11, 0, 13, 13, 9, 1, 9]             94                0.0009
# [1, 11, 0, 11, 8, 3, 7, 15, 6, 15, 8, 12, 9, 2, 10, 5]                 101               0.0010
# [6, 2, 15, 9, 2, 2, 14, 6, 3, 11, 2, 3, 3, 6, 5, 8]                    96                0.0010
# [11, 8, 1, 13, 3, 5, 1, 7, 13, 4, 6, 6, 3, 11, 5, 15]                  102               0.0010
# [0, 0, 0, 0, 3, 12, 15, 10, 0, 14, 9, 11, 8, 8, 15, 3]                 99                0.0010
# [2, 10, 13, 1, 7, 1, 15, 11, 14, 13, 3, 14, 14, 11, 14, 8]             101               0.0010
# [6, 0, 1, 12, 8, 3, 11, 0, 12, 1, 12, 15, 3, 14, 2, 2]                 105               0.0010
# [13, 12, 7, 10, 11, 0, 7, 0, 14, 11, 13, 7, 10, 5, 5, 10]              100               0.0010
# [5, 4, 12, 5, 9, 5, 7, 13, 13, 12, 2, 2, 14, 5, 4, 4]                  93                0.0009
# [8, 3, 7, 13, 8, 1, 7, 11, 11, 8, 9, 0, 1, 3, 15, 6]                   103               0.0010
# [0, 4, 2, 14, 13, 14, 9, 10, 2, 14, 11, 4, 6, 14, 3, 15]               97                0.0010
# [2, 13, 3, 13, 10, 2, 2, 6, 5, 2, 15, 0, 0, 15, 0, 6]                  99                0.0010
# [15, 9, 15, 1, 0, 0, 11, 5, 7, 14, 0, 7, 10, 0, 0, 4]                  95                0.0009
# [0, 5, 10, 9, 15, 4, 14, 8, 12, 4, 1, 3, 13, 2, 13, 15]                106               0.0011
# [15, 8, 14, 14, 12, 3, 10, 15, 15, 0, 6, 1, 3, 5, 2, 13]               102               0.0010
# [3, 5, 11, 2, 13, 6, 15, 5, 3, 6, 1, 14, 9, 12, 15, 13]                100               0.0010
# [10, 9, 1, 6, 6, 9, 4, 6, 1, 8, 14, 14, 14, 14, 5, 1]                  95                0.0009
# [9, 10, 13, 10, 4, 5, 11, 6, 6, 1, 3, 5, 2, 10, 1, 1]                  99                0.0010
# [3, 13, 13, 10, 11, 9, 7, 12, 0, 2, 9, 7, 14, 13, 9, 6]                102               0.0010
# [12, 1, 5, 0, 11, 5, 15, 7, 15, 7, 3, 9, 5, 11, 8, 14]                 106               0.0011
# [3, 8, 9, 0, 9, 1, 0, 4, 14, 14, 7, 0, 0, 15, 10, 6]                   99                0.0010
# [8, 6, 4, 1, 15, 8, 14, 3, 11, 9, 7, 12, 11, 6, 2, 13]                 109               0.0011
# [13, 1, 11, 8, 9, 3, 15, 7, 13, 11, 15, 13, 14, 4, 3, 5]               94                0.0009
# [6, 6, 2, 10, 12, 4, 5, 13, 9, 14, 9, 5, 11, 15, 14, 9]                98                0.0010
# [15, 14, 13, 3, 4, 10, 12, 12, 12, 6, 4, 6, 12, 7, 8, 14]              97                0.0010
# [7, 7, 5, 1, 5, 15, 5, 2, 2, 8, 1, 8, 1, 3, 15, 7]                     100               0.0010
# [3, 5, 7, 8, 0, 7, 10, 11, 3, 13, 3, 13, 2, 7, 1, 14]                  103               0.0010
# [15, 3, 1, 6, 7, 11, 2, 6, 14, 2, 8, 8, 6, 6, 2, 11]                   96                0.0010
# [4, 3, 3, 0, 7, 4, 0, 7, 15, 11, 10, 9, 5, 1, 4, 10]                   104               0.0010
# [6, 7, 11, 1, 9, 6, 5, 4, 14, 4, 1, 4, 3, 11, 0, 0]                    98                0.0010
# [3, 8, 0, 9, 1, 7, 4, 0, 5, 2, 14, 7, 6, 3, 15, 11]                    109               0.0011
# [6, 3, 3, 11, 2, 12, 6, 0, 10, 11, 5, 13, 2, 12, 12, 4]                102               0.0010
# [3, 14, 12, 5, 6, 6, 6, 2, 15, 10, 8, 0, 7, 13, 3, 10]                 104               0.0010
# [14, 5, 4, 6, 9, 6, 5, 3, 12, 13, 13, 1, 9, 12, 0, 9]                  102               0.0010
# [0, 7, 8, 9, 0, 12, 11, 12, 14, 1, 14, 14, 13, 1, 6, 4]                98                0.0010
# [8, 6, 1, 8, 15, 6, 7, 8, 14, 14, 2, 8, 4, 6, 3, 3]                    97                0.0010
# [13, 3, 15, 9, 0, 1, 12, 9, 14, 12, 4, 10, 15, 2, 12, 10]              103               0.0010
# [4, 12, 5, 9, 4, 4, 4, 8, 14, 15, 0, 2, 4, 10, 4, 8]                   94                0.0009
# [4, 3, 3, 8, 7, 0, 6, 10, 15, 1, 15, 10, 4, 14, 11, 14]                102               0.0010
# [5, 7, 3, 3, 12, 11, 7, 6, 15, 6, 6, 0, 13, 7, 1, 5]                   97                0.0010
# [13, 13, 1, 1, 6, 8, 6, 9, 11, 5, 5, 8, 13, 4, 7, 3]                   105               0.0010
# [5, 6, 1, 8, 1, 0, 1, 0, 0, 0, 1, 7, 11, 15, 13, 10]                   90                0.0009
# [3, 0, 13, 13, 4, 12, 12, 1, 5, 5, 9, 10, 6, 0, 6, 6]                  101               0.0010
# [11, 0, 0, 7, 0, 14, 0, 12, 5, 11, 11, 8, 5, 1, 7, 4]                  101               0.0010
# [10, 6, 14, 0, 12, 8, 0, 14, 14, 12, 13, 3, 13, 14, 7, 8]              98                0.0010
# [2, 14, 12, 12, 8, 8, 5, 15, 2, 5, 15, 13, 3, 5, 5, 13]                102               0.0010
# [11, 6, 1, 10, 5, 5, 14, 10, 6, 7, 8, 5, 9, 8, 5, 10]                  101               0.0010
# [5, 13, 12, 4, 15, 7, 10, 10, 1, 13, 6, 13, 15, 3, 8, 0]               105               0.0010
# [3, 8, 7, 10, 7, 11, 4, 15, 3, 8, 5, 2, 1, 3, 4, 9]                    101               0.0010
# [13, 9, 5, 5, 6, 5, 8, 4, 2, 4, 12, 11, 0, 4, 12, 9]                   96                0.0010
# [4, 2, 11, 0, 7, 5, 14, 6, 1, 5, 0, 0, 10, 3, 13, 6]                   105               0.0010
# [11, 14, 6, 3, 12, 6, 9, 3, 7, 13, 4, 8, 4, 4, 3, 4]                   97                0.0010
# [15, 1, 8, 10, 8, 3, 11, 13, 11, 9, 3, 13, 11, 6, 5, 8]                100               0.0010
# [12, 6, 6, 1, 10, 1, 11, 10, 10, 4, 4, 7, 0, 10, 9, 11]                95                0.0009
# [14, 4, 3, 5, 14, 1, 4, 4, 11, 15, 14, 7, 3, 2, 13, 5]                 102               0.0010
# [1, 7, 2, 1, 13, 3, 2, 0, 4, 13, 4, 12, 12, 15, 2, 11]                 102               0.0010
# [14, 6, 3, 2, 4, 0, 1, 9, 9, 4, 2, 14, 2, 0, 13, 13]                   98                0.0010
# [3, 8, 7, 3, 1, 11, 8, 12, 0, 8, 7, 0, 14, 13, 13, 2]                  101               0.0010
# [0, 13, 4, 6, 8, 9, 0, 7, 7, 9, 7, 3, 1, 14, 8, 13]                    102               0.0010
# [12, 15, 9, 15, 1, 3, 0, 6, 4, 14, 13, 10, 0, 8, 14, 15]               105               0.0010
# [1, 2, 3, 9, 0, 9, 6, 6, 5, 4, 13, 1, 6, 1, 2, 6]                      97                0.0010
# [15, 14, 1, 13, 5, 3, 6, 5, 6, 5, 10, 8, 3, 9, 15, 14]                 97                0.0010
# [15, 10, 0, 14, 5, 14, 9, 8, 3, 6, 12, 7, 14, 3, 5, 3]                 100               0.0010
# [7, 15, 9, 2, 14, 15, 2, 6, 0, 4, 4, 4, 14, 15, 13, 2]                 100               0.0010
# [10, 13, 7, 10, 6, 2, 8, 15, 8, 14, 13, 5, 10, 14, 3, 3]               101               0.0010
# [11, 0, 12, 14, 11, 14, 4, 5, 5, 6, 1, 8, 5, 13, 6, 0]                 99                0.0010
# [1, 12, 11, 2, 6, 11, 2, 0, 4, 7, 13, 10, 9, 7, 13, 9]                 104               0.0010
# [3, 9, 4, 4, 12, 11, 1, 4, 0, 0, 8, 3, 10, 15, 11, 0]                  103               0.0010
# [3, 12, 9, 13, 11, 8, 5, 2, 9, 1, 0, 11, 6, 4, 3, 8]                   105               0.0010
# [6, 10, 5, 9, 5, 1, 7, 9, 5, 6, 6, 9, 4, 7, 2, 10]                     95                0.0009
# [1, 10, 11, 8, 7, 1, 7, 9, 8, 11, 13, 15, 8, 14, 15, 11]               88                0.0009
# [8, 12, 6, 4, 5, 0, 6, 3, 9, 8, 5, 2, 9, 12, 0, 11]                    102               0.0010
# [4, 11, 4, 8, 7, 6, 7, 5, 1, 4, 0, 15, 4, 8, 9, 7]                     97                0.0010
# [0, 12, 11, 12, 0, 3, 5, 13, 5, 14, 15, 1, 0, 8, 11, 11]               101               0.0010
# [2, 8, 4, 0, 9, 10, 15, 5, 12, 6, 0, 11, 0, 13, 15, 15]                104               0.0010
# [0, 9, 0, 10, 9, 4, 13, 7, 11, 5, 1, 7, 6, 3, 0, 0]                    100               0.0010
# [8, 4, 14, 11, 5, 12, 8, 5, 11, 8, 1, 0, 13, 15, 9, 0]                 104               0.0010
# [10, 2, 1, 4, 0, 2, 12, 2, 3, 10, 12, 11, 1, 15, 12, 9]                101               0.0010
# [5, 5, 12, 7, 11, 2, 4, 5, 2, 14, 7, 1, 10, 9, 3, 1]                   99                0.0010
# [11, 6, 15, 12, 10, 10, 2, 0, 14, 13, 15, 3, 8, 4, 3, 10]              97                0.0010
# [12, 12, 13, 2, 13, 8, 11, 9, 11, 9, 5, 13, 10, 2, 10, 1]              98                0.0010
# [4, 14, 12, 15, 6, 7, 7, 15, 15, 10, 15, 1, 9, 14, 12, 0]              103               0.0010
# [4, 13, 6, 15, 5, 10, 7, 1, 5, 9, 3, 10, 6, 7, 0, 2]                   100               0.0010
# [10, 10, 14, 2, 9, 3, 6, 8, 9, 15, 1, 12, 10, 6, 0, 3]                 108               0.0011
# [2, 14, 9, 15, 11, 1, 12, 9, 13, 13, 11, 7, 13, 11, 12, 5]             100               0.0010
# [13, 1, 8, 10, 8, 10, 0, 13, 10, 3, 14, 12, 1, 2, 12, 1]               100               0.0010
# [6, 15, 14, 4, 6, 6, 7, 14, 13, 3, 8, 14, 2, 5, 0, 12]                 103               0.0010
# [10, 0, 15, 9, 5, 14, 0, 5, 6, 10, 5, 14, 1, 3, 0, 14]                 101               0.0010
# [4, 7, 0, 1, 11, 14, 2, 8, 13, 4, 2, 15, 7, 15, 3, 4]                  101               0.0010
# [13, 10, 10, 3, 14, 3, 13, 0, 0, 2, 9, 11, 12, 5, 3, 13]               98                0.0010
# [0, 4, 8, 5, 7, 14, 11, 6, 3, 14, 4, 7, 7, 15, 3, 1]                   104               0.0010
# [5, 5, 4, 3, 4, 8, 6, 13, 6, 4, 8, 8, 2, 2, 10, 1]                     100               0.0010
# [13, 10, 3, 7, 15, 8, 5, 10, 12, 2, 13, 7, 12, 6, 5, 4]                101               0.0010
# [7, 13, 2, 1, 8, 6, 11, 13, 9, 12, 1, 13, 7, 8, 8, 3]                  102               0.0010
# [10, 9, 12, 12, 4, 10, 0, 13, 0, 8, 11, 1, 13, 6, 5, 11]               105               0.0010
# [12, 8, 11, 14, 1, 11, 9, 5, 5, 11, 3, 9, 7, 1, 3, 7]                  101               0.0010
# [10, 13, 5, 8, 14, 13, 11, 9, 10, 6, 14, 0, 15, 2, 9, 3]               103               0.0010
# [3, 5, 13, 12, 15, 9, 10, 11, 5, 0, 15, 2, 11, 9, 0, 4]                99                0.0010
# [15, 10, 14, 7, 4, 14, 7, 5, 3, 3, 12, 5, 12, 13, 3, 11]               100               0.0010
# [9, 2, 12, 15, 6, 3, 14, 7, 14, 12, 10, 1, 12, 5, 10, 15]              100               0.0010
# [1, 11, 0, 15, 6, 6, 11, 14, 13, 10, 7, 15, 4, 12, 13, 15]             105               0.0010
# [9, 12, 13, 9, 2, 7, 4, 11, 10, 9, 3, 10, 12, 15, 4, 11]               99                0.0010
# [12, 6, 8, 4, 7, 4, 14, 9, 9, 3, 1, 6, 0, 0, 0, 8]                     103               0.0010
# [9, 15, 5, 12, 11, 10, 13, 3, 14, 13, 7, 15, 2, 2, 5, 7]               103               0.0010
# [9, 12, 0, 14, 3, 13, 0, 6, 8, 5, 13, 4, 3, 4, 11, 2]                  106               0.0011
# [12, 13, 12, 13, 5, 3, 9, 6, 3, 14, 5, 9, 11, 0, 13, 13]               93                0.0009
# [8, 3, 3, 14, 11, 15, 3, 11, 5, 1, 5, 0, 4, 8, 4, 9]                   106               0.0011
# [3, 5, 0, 11, 8, 8, 8, 4, 13, 13, 2, 11, 15, 15, 5, 12]                97                0.0010
# [5, 2, 0, 9, 4, 10, 12, 8, 4, 5, 12, 5, 7, 7, 15, 6]                   103               0.0010
# [12, 5, 1, 14, 7, 5, 4, 2, 11, 1, 10, 4, 4, 12, 14, 0]                 102               0.0010
# [0, 3, 15, 7, 0, 12, 15, 12, 8, 12, 5, 7, 0, 4, 4, 15]                 96                0.0010
# [8, 1, 2, 10, 8, 5, 2, 7, 8, 0, 4, 14, 2, 5, 3, 11]                    97                0.0010
# [6, 1, 2, 11, 10, 6, 8, 14, 15, 10, 1, 4, 1, 3, 12, 2]                 105               0.0010
# [5, 5, 4, 10, 7, 12, 0, 12, 7, 15, 6, 8, 13, 9, 15, 14]                104               0.0010
# [3, 6, 13, 2, 8, 4, 5, 4, 9, 9, 4, 1, 2, 8, 13, 9]                     97                0.0010
# [1, 0, 7, 14, 11, 11, 10, 11, 6, 12, 8, 1, 2, 7, 8, 0]                 99                0.0010
# [9, 9, 5, 11, 14, 15, 9, 0, 7, 11, 10, 1, 14, 4, 14, 14]               97                0.0010
# [7, 9, 6, 14, 15, 11, 13, 6, 1, 11, 5, 9, 8, 9, 11, 13]                103               0.0010
# [7, 10, 4, 9, 7, 6, 15, 4, 6, 15, 6, 11, 13, 14, 10, 3]                101               0.0010
# [6, 3, 5, 14, 5, 5, 15, 15, 0, 6, 9, 1, 9, 8, 8, 6]                    104               0.0010
# [12, 0, 8, 6, 11, 3, 11, 6, 14, 11, 0, 8, 4, 0, 7, 14]                 103               0.0010
# [14, 4, 11, 10, 1, 5, 4, 2, 7, 14, 13, 0, 10, 2, 0, 0]                 97                0.0010
# [14, 11, 8, 2, 15, 13, 14, 11, 10, 2, 8, 10, 13, 8, 13, 14]            95                0.0009
# [5, 3, 10, 2, 6, 15, 14, 14, 12, 15, 6, 4, 6, 8, 12, 12]               103               0.0010
# [1, 6, 6, 9, 13, 14, 13, 10, 6, 8, 3, 3, 0, 9, 3, 11]                  100               0.0010
# [11, 1, 4, 0, 10, 1, 11, 4, 13, 5, 8, 12, 4, 11, 3, 14]                101               0.0010
# [12, 10, 13, 13, 0, 1, 7, 12, 3, 0, 8, 0, 1, 13, 12, 2]                100               0.0010
# [9, 3, 13, 4, 1, 13, 9, 4, 1, 15, 6, 10, 11, 6, 11, 12]                102               0.0010
# [0, 15, 7, 3, 7, 8, 2, 8, 8, 0, 8, 4, 7, 8, 10, 1]                     93                0.0009
# [7, 14, 6, 5, 8, 1, 10, 9, 1, 6, 11, 9, 2, 11, 8, 13]                  102               0.0010
# [4, 13, 5, 9, 10, 9, 3, 12, 14, 3, 13, 12, 3, 3, 9, 15]                96                0.0010
# [0, 6, 6, 10, 13, 11, 12, 2, 12, 4, 15, 5, 14, 12, 0, 2]               102               0.0010
# [5, 12, 2, 12, 14, 12, 8, 1, 11, 11, 1, 14, 5, 9, 9, 9]                105               0.0010
# [13, 8, 6, 11, 7, 11, 12, 10, 3, 8, 3, 14, 3, 11, 4, 13]               99                0.0010
# [14, 5, 5, 1, 11, 9, 11, 10, 12, 15, 13, 2, 5, 6, 3, 1]                102               0.0010
# [13, 2, 11, 12, 8, 10, 7, 13, 15, 15, 14, 2, 15, 14, 3, 5]             96                0.0010
# [15, 15, 0, 8, 9, 3, 6, 5, 0, 4, 13, 1, 5, 8, 3, 13]                   97                0.0010
# [6, 13, 15, 5, 6, 9, 2, 11, 7, 8, 5, 7, 6, 9, 8, 6]                    90                0.0009
# [9, 9, 3, 2, 14, 2, 14, 8, 0, 1, 14, 6, 8, 7, 2, 7]                    99                0.0010
# [1, 15, 4, 15, 0, 1, 9, 4, 9, 4, 3, 2, 7, 3, 13, 13]                   102               0.0010
# [6, 12, 7, 4, 10, 3, 10, 4, 12, 8, 2, 13, 13, 15, 1, 14]               111               0.0011
# [12, 0, 15, 15, 0, 13, 8, 1, 10, 11, 5, 8, 3, 14, 4, 4]                104               0.0010
# [7, 3, 10, 11, 14, 7, 1, 14, 2, 14, 15, 2, 2, 2, 15, 12]               99                0.0010
# [12, 0, 10, 7, 7, 12, 12, 10, 10, 7, 12, 8, 10, 1, 5, 14]              91                0.0009
# [12, 14, 12, 5, 14, 10, 0, 0, 14, 2, 8, 10, 4, 2, 14, 10]              101               0.0010
# [9, 3, 9, 7, 1, 2, 1, 10, 9, 14, 4, 13, 11, 10, 3, 7]                  101               0.0010
# [3, 2, 3, 1, 15, 15, 0, 14, 6, 6, 2, 1, 11, 8, 3, 3]                   102               0.0010
# [15, 3, 9, 13, 10, 11, 15, 4, 0, 12, 7, 1, 9, 8, 6, 1]                 103               0.0010
# [8, 7, 1, 11, 3, 15, 10, 1, 10, 2, 5, 2, 0, 3, 4, 0]                   103               0.0010
# [7, 2, 0, 0, 14, 6, 3, 14, 3, 3, 14, 7, 9, 10, 4, 9]                   91                0.0009
# [1, 14, 0, 2, 1, 8, 10, 3, 8, 4, 8, 14, 11, 8, 12, 15]                 99                0.0010
# [1, 13, 14, 5, 14, 14, 14, 9, 0, 3, 8, 11, 7, 10, 7, 10]               101               0.0010
# [4, 4, 5, 4, 3, 12, 10, 15, 3, 11, 13, 12, 15, 3, 14, 10]              95                0.0009
# [3, 8, 12, 8, 15, 12, 0, 4, 6, 12, 4, 8, 13, 12, 13, 2]                93                0.0009
# [9, 11, 1, 7, 2, 10, 14, 3, 7, 6, 5, 10, 1, 12, 4, 4]                  103               0.0010
# [4, 2, 4, 6, 5, 1, 14, 11, 2, 2, 9, 2, 3, 1, 6, 14]                    100               0.0010
# [9, 3, 13, 2, 13, 5, 1, 8, 10, 11, 2, 8, 14, 0, 4, 9]                  105               0.0010
# [1, 14, 15, 4, 11, 6, 1, 9, 5, 3, 4, 7, 7, 3, 2, 9]                    100               0.0010
# [14, 4, 6, 10, 11, 0, 1, 13, 0, 13, 11, 15, 2, 0, 11, 7]               97                0.0010
# [4, 9, 8, 4, 8, 2, 14, 4, 0, 15, 9, 7, 8, 11, 13, 6]                   99                0.0010
# [15, 12, 11, 1, 0, 7, 11, 0, 0, 2, 9, 6, 6, 8, 1, 7]                   102               0.0010
# [12, 1, 10, 11, 10, 9, 3, 7, 11, 6, 0, 1, 4, 1, 11, 3]                 97                0.0010
# [10, 7, 7, 1, 14, 0, 14, 15, 3, 9, 3, 11, 9, 1, 3, 3]                  100               0.0010
# [2, 15, 5, 2, 4, 2, 5, 14, 15, 14, 8, 15, 2, 7, 13, 6]                 99                0.0010
# [0, 6, 1, 13, 5, 0, 10, 1, 9, 3, 9, 14, 2, 0, 0, 4]                    103               0.0010
# [12, 14, 0, 11, 14, 2, 11, 9, 4, 9, 9, 1, 6, 10, 15, 6]                107               0.0011
# [0, 9, 15, 15, 3, 6, 2, 3, 4, 14, 12, 5, 10, 2, 13, 15]                106               0.0011
# [13, 11, 9, 2, 3, 13, 3, 14, 1, 12, 12, 6, 2, 3, 12, 11]               102               0.0010
# [15, 4, 6, 11, 0, 10, 15, 0, 3, 12, 4, 14, 12, 4, 11, 7]               102               0.0010
# [11, 9, 3, 0, 6, 10, 1, 11, 4, 12, 6, 13, 14, 1, 12, 8]                108               0.0011
# [9, 2, 14, 14, 8, 3, 0, 9, 11, 6, 14, 13, 10, 6, 0, 8]                 103               0.0010
# [10, 12, 1, 3, 10, 10, 14, 1, 0, 1, 5, 3, 0, 15, 4, 6]                 101               0.0010
# [12, 13, 9, 2, 0, 1, 1, 8, 13, 15, 14, 7, 6, 11, 6, 10]                107               0.0011
# [3, 12, 7, 2, 5, 14, 1, 11, 0, 11, 15, 15, 10, 3, 10, 3]               108               0.0011
# [8, 1, 8, 11, 4, 8, 15, 11, 5, 8, 10, 10, 13, 14, 12, 7]               100               0.0010
# [5, 4, 1, 10, 1, 11, 11, 11, 11, 7, 1, 15, 4, 10, 7, 3]                96                0.0010
# [7, 8, 8, 2, 1, 7, 1, 14, 8, 12, 10, 12, 2, 2, 15, 3]                  100               0.0010
# [8, 13, 2, 1, 5, 9, 6, 11, 3, 13, 6, 7, 0, 1, 13, 13]                  96                0.0010
# [5, 3, 3, 4, 6, 8, 15, 7, 6, 0, 6, 10, 0, 7, 12, 0]                    103               0.0010
# [7, 1, 6, 7, 4, 4, 14, 14, 11, 3, 4, 15, 5, 1, 3, 8]                   100               0.0010
# [6, 14, 2, 13, 10, 14, 8, 10, 5, 0, 5, 1, 1, 1, 3, 6]                  101               0.0010
# [2, 8, 9, 10, 6, 3, 13, 7, 6, 11, 7, 13, 6, 14, 6, 8]                  94                0.0009
# [9, 3, 14, 2, 14, 6, 5, 13, 9, 6, 15, 15, 10, 0, 4, 4]                 109               0.0011
# [5, 2, 12, 0, 7, 4, 8, 12, 8, 9, 10, 13, 11, 1, 14, 2]                 103               0.0010
# [11, 9, 12, 0, 2, 13, 4, 0, 11, 7, 14, 9, 12, 9, 5, 11]                98                0.0010
# [3, 5, 1, 6, 7, 10, 5, 0, 2, 8, 13, 1, 1, 1, 13, 1]                    92                0.0009
# [8, 13, 9, 3, 7, 1, 10, 15, 7, 13, 3, 3, 3, 14, 10, 12]                96                0.0010
# [2, 12, 11, 8, 12, 12, 8, 13, 5, 10, 0, 9, 15, 3, 9, 15]               105               0.0010
# [10, 12, 15, 7, 15, 5, 12, 2, 13, 13, 11, 4, 13, 6, 7, 5]              99                0.0010
# [12, 5, 9, 9, 15, 4, 12, 10, 9, 13, 0, 5, 6, 2, 9, 15]                 102               0.0010
# [9, 4, 7, 13, 10, 7, 13, 13, 2, 10, 9, 11, 13, 6, 13, 9]               95                0.0009
# [2, 6, 9, 0, 3, 10, 10, 1, 11, 11, 12, 3, 4, 3, 10, 3]                 100               0.0010
# [10, 8, 7, 9, 14, 6, 3, 13, 2, 6, 14, 2, 3, 13, 11, 10]                99                0.0010
# [5, 10, 11, 15, 5, 2, 5, 5, 13, 1, 6, 6, 10, 4, 5, 15]                 99                0.0010
# [6, 12, 11, 15, 2, 7, 8, 3, 12, 10, 5, 6, 8, 13, 13, 5]                105               0.0010
# [4, 3, 11, 12, 5, 12, 13, 2, 3, 4, 15, 6, 12, 2, 13, 5]                94                0.0009
# [1, 7, 3, 3, 6, 1, 12, 14, 1, 12, 0, 11, 11, 11, 0, 9]                 100               0.0010
# [2, 10, 8, 6, 7, 0, 8, 8, 4, 4, 15, 5, 1, 0, 0, 15]                    102               0.0010
# [15, 4, 2, 9, 11, 2, 4, 13, 2, 7, 10, 15, 2, 14, 1, 0]                 101               0.0010
# [4, 15, 10, 5, 0, 5, 14, 11, 1, 11, 12, 8, 15, 2, 13, 8]               104               0.0010
# [8, 4, 8, 5, 5, 11, 2, 6, 6, 7, 2, 6, 9, 14, 14, 1]                    104               0.0010
# [3, 6, 6, 8, 12, 12, 8, 0, 9, 12, 9, 3, 4, 13, 0, 11]                  98                0.0010
# [3, 10, 7, 0, 7, 7, 1, 9, 4, 1, 5, 14, 13, 12, 5, 13]                  100               0.0010
# [11, 4, 9, 15, 3, 13, 8, 2, 2, 7, 15, 3, 0, 12, 7, 7]                  104               0.0010
# [5, 1, 14, 1, 14, 6, 10, 5, 3, 3, 10, 10, 10, 9, 13, 14]               93                0.0009
# ...
# LOOP: 138 / 10000 --> Max fitness: 114
# LOOP: 139 / 10000 --> Max fitness: 115
# LOOP: 140 / 10000 --> Max fitness: 116
# LOOP: 141 / 10000 --> Max fitness: 116
# LOOP: 142 / 10000 --> Max fitness: 114
# LOOP: 143 / 10000 --> Max fitness: 113
# LOOP: 144 / 10000 --> Max fitness: 115
# LOOP: 145 / 10000 --> Max fitness: 115
# LOOP: 146 / 10000 --> Max fitness: 117
# LOOP: 147 / 10000 --> Max fitness: 115
# LOOP: 148 / 10000 --> Max fitness: 115
# LOOP: 149 / 10000 --> Max fitness: 115
# LOOP: 150 / 10000 --> Max fitness: 115
# LOOP: 151 / 10000 --> Max fitness: 114
# LOOP: 152 / 10000 --> Max fitness: 116
# LOOP: 153 / 10000 --> Max fitness: 116
# LOOP: 154 / 10000 --> Max fitness: 114
# LOOP: 155 / 10000 --> Max fitness: 115
# LOOP: 156 / 10000 --> Max fitness: 117
# LOOP: 157 / 10000 --> Max fitness: 114
# LOOP: 158 / 10000 --> Max fitness: 115
# LOOP: 159 / 10000 --> Max fitness: 114
# LOOP: 160 / 10000 --> Max fitness: 115
# LOOP: 161 / 10000 --> Max fitness: 115
# LOOP: 162 / 10000 --> Max fitness: 116
# LOOP: 163 / 10000 --> Max fitness: 116
# LOOP: 164 / 10000 --> Max fitness: 115
# LOOP: 165 / 10000 --> Max fitness: 116
# LOOP: 166 / 10000 --> Max fitness: 114
# LOOP: 167 / 10000 --> Max fitness: 117
# LOOP: 168 / 10000 --> Max fitness: 114
# LOOP: 169 / 10000 --> Max fitness: 114
# LOOP: 170 / 10000 --> Max fitness: 116
# LOOP: 171 / 10000 --> Max fitness: 115
# LOOP: 172 / 10000 --> Max fitness: 115
# LOOP: 173 / 10000 --> Max fitness: 115
# LOOP: 174 / 10000 --> Max fitness: 116
# LOOP: 175 / 10000 --> Max fitness: 115
# LOOP: 176 / 10000 --> Max fitness: 116
# LOOP: 177 / 10000 --> Max fitness: 115
# LOOP: 178 / 10000 --> Max fitness: 115
# LOOP: 179 / 10000 --> Max fitness: 114
# LOOP: 180 / 10000 --> Max fitness: 115
# LOOP: 181 / 10000 --> Max fitness: 116
# LOOP: 182 / 10000 --> Max fitness: 116
# LOOP: 183 / 10000 --> Max fitness: 116
# LOOP: 184 / 10000 --> Max fitness: 116
# LOOP: 185 / 10000 --> Max fitness: 115
# LOOP: 186 / 10000 --> Max fitness: 115
# LOOP: 187 / 10000 --> Max fitness: 116
# LOOP: 188 / 10000 --> Max fitness: 114
# LOOP: 189 / 10000 --> Max fitness: 115
# LOOP: 190 / 10000 --> Max fitness: 116
# LOOP: 191 / 10000 --> Max fitness: 116
# LOOP: 192 / 10000 --> Max fitness: 116
# LOOP: 193 / 10000 --> Max fitness: 116
# LOOP: 194 / 10000 --> Max fitness: 116
# LOOP: 195 / 10000 --> Max fitness: 114
# LOOP: 196 / 10000 --> Max fitness: 115
# LOOP: 197 / 10000 --> Max fitness: 116
# LOOP: 198 / 10000 --> Max fitness: 116
# LOOP: 199 / 10000 --> Max fitness: 115
# LOOP: 200 / 10000 --> Max fitness: 115
# LOOP: 201 / 10000 --> Max fitness: 115
# LOOP: 202 / 10000 --> Max fitness: 117
# LOOP: 203 / 10000 --> Max fitness: 115
# LOOP: 204 / 10000 --> Max fitness: 114
# LOOP: 205 / 10000 --> Max fitness: 115
# LOOP: 206 / 10000 --> Max fitness: 115
# LOOP: 207 / 10000 --> Max fitness: 116
# LOOP: 208 / 10000 --> Max fitness: 115
# LOOP: 209 / 10000 --> Max fitness: 115
# LOOP: 210 / 10000 --> Max fitness: 116
# LOOP: 211 / 10000 --> Max fitness: 116
# LOOP: 212 / 10000 --> Max fitness: 116
# LOOP: 213 / 10000 --> Max fitness: 116
# LOOP: 214 / 10000 --> Max fitness: 115
# LOOP: 215 / 10000 --> Max fitness: 118
# LOOP: 216 / 10000 --> Max fitness: 116
# LOOP: 217 / 10000 --> Max fitness: 115
# LOOP: 218 / 10000 --> Max fitness: 117
# LOOP: 219 / 10000 --> Max fitness: 115
# LOOP: 220 / 10000 --> Max fitness: 115
# LOOP: 221 / 10000 --> Max fitness: 115
# LOOP: 222 / 10000 --> Max fitness: 115
# LOOP: 223 / 10000 --> Max fitness: 115
# LOOP: 224 / 10000 --> Max fitness: 115
# LOOP: 225 / 10000 --> Max fitness: 115
# LOOP: 226 / 10000 --> Max fitness: 116
# LOOP: 227 / 10000 --> Max fitness: 116
# LOOP: 228 / 10000 --> Max fitness: 114
# LOOP: 229 / 10000 --> Max fitness: 115
# LOOP: 230 / 10000 --> Max fitness: 115
# LOOP: 231 / 10000 --> Max fitness: 115
# LOOP: 232 / 10000 --> Max fitness: 115
# LOOP: 233 / 10000 --> Max fitness: 114
# LOOP: 234 / 10000 --> Max fitness: 116
# LOOP: 235 / 10000 --> Max fitness: 116
# LOOP: 236 / 10000 --> Max fitness: 117
# LOOP: 237 / 10000 --> Max fitness: 114
# LOOP: 238 / 10000 --> Max fitness: 116
# LOOP: 239 / 10000 --> Max fitness: 115
# LOOP: 240 / 10000 --> Max fitness: 116
# LOOP: 241 / 10000 --> Max fitness: 114
# LOOP: 242 / 10000 --> Max fitness: 116
# LOOP: 243 / 10000 --> Max fitness: 115
# LOOP: 244 / 10000 --> Max fitness: 114
# LOOP: 245 / 10000 --> Max fitness: 116
# LOOP: 246 / 10000 --> Max fitness: 115
# LOOP: 247 / 10000 --> Max fitness: 115
# LOOP: 248 / 10000 --> Max fitness: 115
# LOOP: 249 / 10000 --> Max fitness: 114
# LOOP: 250 / 10000 --> Max fitness: 114
# LOOP: 251 / 10000 --> Max fitness: 115
# LOOP: 252 / 10000 --> Max fitness: 115
# LOOP: 253 / 10000 --> Max fitness: 116
# LOOP: 254 / 10000 --> Max fitness: 115
# LOOP: 255 / 10000 --> Max fitness: 115
# LOOP: 256 / 10000 --> Max fitness: 115
# LOOP: 257 / 10000 --> Max fitness: 115
# LOOP: 258 / 10000 --> Max fitness: 115
# LOOP: 259 / 10000 --> Max fitness: 115
# LOOP: 260 / 10000 --> Max fitness: 115
# LOOP: 261 / 10000 --> Max fitness: 116
# LOOP: 262 / 10000 --> Max fitness: 115
# LOOP: 263 / 10000 --> Max fitness: 115
# LOOP: 264 / 10000 --> Max fitness: 116
# LOOP: 265 / 10000 --> Max fitness: 115
# LOOP: 266 / 10000 --> Max fitness: 116
# LOOP: 267 / 10000 --> Max fitness: 115
# LOOP: 268 / 10000 --> Max fitness: 117
# LOOP: 269 / 10000 --> Max fitness: 116
# LOOP: 270 / 10000 --> Max fitness: 115
# LOOP: 271 / 10000 --> Max fitness: 114
# LOOP: 272 / 10000 --> Max fitness: 115
# LOOP: 273 / 10000 --> Max fitness: 114
# LOOP: 274 / 10000 --> Max fitness: 115
# LOOP: 275 / 10000 --> Max fitness: 115
# LOOP: 276 / 10000 --> Max fitness: 116
# LOOP: 277 / 10000 --> Max fitness: 115
# LOOP: 278 / 10000 --> Max fitness: 114
# LOOP: 279 / 10000 --> Max fitness: 114
# LOOP: 280 / 10000 --> Max fitness: 117
# LOOP: 281 / 10000 --> Max fitness: 116
# LOOP: 282 / 10000 --> Max fitness: 115
# LOOP: 283 / 10000 --> Max fitness: 115
# LOOP: 284 / 10000 --> Max fitness: 115
# LOOP: 285 / 10000 --> Max fitness: 114
# LOOP: 286 / 10000 --> Max fitness: 115
# LOOP: 287 / 10000 --> Max fitness: 115
# LOOP: 288 / 10000 --> Max fitness: 115
# LOOP: 289 / 10000 --> Max fitness: 116
# LOOP: 290 / 10000 --> Max fitness: 115
# LOOP: 291 / 10000 --> Max fitness: 114
# LOOP: 292 / 10000 --> Max fitness: 119
# LOOP: 293 / 10000 --> Max fitness: 116
# LOOP: 294 / 10000 --> Max fitness: 115
# LOOP: 295 / 10000 --> Max fitness: 114
# LOOP: 296 / 10000 --> Max fitness: 116
# LOOP: 297 / 10000 --> Max fitness: 117
# LOOP: 298 / 10000 --> Max fitness: 119
# LOOP: 299 / 10000 --> Max fitness: 115
# LOOP: 300 / 10000 --> Max fitness: 116
# LOOP: 301 / 10000 --> Max fitness: 115
# LOOP: 302 / 10000 --> Max fitness: 117
# LOOP: 303 / 10000 --> Max fitness: 115
# LOOP: 304 / 10000 --> Max fitness: 115
# LOOP: 305 / 10000 --> Max fitness: 115
# LOOP: 306 / 10000 --> Max fitness: 115
# LOOP: 307 / 10000 --> Max fitness: 116
# LOOP: 308 / 10000 --> Max fitness: 116
# LOOP: 309 / 10000 --> Max fitness: 116
# LOOP: 310 / 10000 --> Max fitness: 116
# LOOP: 311 / 10000 --> Max fitness: 115
# LOOP: 312 / 10000 --> Max fitness: 116
# LOOP: 313 / 10000 --> Max fitness: 115
# LOOP: 314 / 10000 --> Max fitness: 115
# LOOP: 315 / 10000 --> Max fitness: 115
# LOOP: 316 / 10000 --> Max fitness: 115
# LOOP: 317 / 10000 --> Max fitness: 116
# LOOP: 318 / 10000 --> Max fitness: 115
# LOOP: 319 / 10000 --> Max fitness: 115
# LOOP: 320 / 10000 --> Max fitness: 115
# LOOP: 321 / 10000 --> Max fitness: 116
# LOOP: 322 / 10000 --> Max fitness: 115
# LOOP: 323 / 10000 --> Max fitness: 117
# LOOP: 324 / 10000 --> Max fitness: 116
# LOOP: 325 / 10000 --> Max fitness: 116
# LOOP: 326 / 10000 --> Max fitness: 114
# LOOP: 327 / 10000 --> Max fitness: 115
# LOOP: 328 / 10000 --> Max fitness: 115
# LOOP: 329 / 10000 --> Max fitness: 116
# LOOP: 330 / 10000 --> Max fitness: 115
# LOOP: 331 / 10000 --> Max fitness: 116
# LOOP: 332 / 10000 --> Max fitness: 116
# LOOP: 333 / 10000 --> Max fitness: 116
# LOOP: 334 / 10000 --> Max fitness: 115
# LOOP: 335 / 10000 --> Max fitness: 115
# LOOP: 336 / 10000 --> Max fitness: 115
# LOOP: 337 / 10000 --> Max fitness: 115
# LOOP: 338 / 10000 --> Max fitness: 115
# LOOP: 339 / 10000 --> Max fitness: 116
# LOOP: 340 / 10000 --> Max fitness: 115
# LOOP: 341 / 10000 --> Max fitness: 114
# LOOP: 342 / 10000 --> Max fitness: 115
# LOOP: 343 / 10000 --> Max fitness: 116
# LOOP: 344 / 10000 --> Max fitness: 114
# LOOP: 345 / 10000 --> Max fitness: 115
# LOOP: 346 / 10000 --> Max fitness: 115
# LOOP: 347 / 10000 --> Max fitness: 117
# LOOP: 348 / 10000 --> Max fitness: 116
# LOOP: 349 / 10000 --> Max fitness: 116
# LOOP: 350 / 10000 --> Max fitness: 115
# LOOP: 351 / 10000 --> Max fitness: 115
# LOOP: 352 / 10000 --> Max fitness: 117
# LOOP: 353 / 10000 --> Max fitness: 114
# LOOP: 354 / 10000 --> Max fitness: 116
# LOOP: 355 / 10000 --> Max fitness: 116
# LOOP: 356 / 10000 --> Max fitness: 114
# LOOP: 357 / 10000 --> Max fitness: 116
# LOOP: 358 / 10000 --> Max fitness: 115
# LOOP: 359 / 10000 --> Max fitness: 114
# LOOP: 360 / 10000 --> Max fitness: 116
# LOOP: 361 / 10000 --> Max fitness: 116
# LOOP: 362 / 10000 --> Max fitness: 113
# LOOP: 363 / 10000 --> Max fitness: 114
# LOOP: 364 / 10000 --> Max fitness: 116
# LOOP: 365 / 10000 --> Max fitness: 114
# LOOP: 366 / 10000 --> Max fitness: 116
# LOOP: 367 / 10000 --> Max fitness: 115
# LOOP: 368 / 10000 --> Max fitness: 115
# LOOP: 369 / 10000 --> Max fitness: 114
# LOOP: 370 / 10000 --> Max fitness: 117
# LOOP: 371 / 10000 --> Max fitness: 117
# LOOP: 372 / 10000 --> Max fitness: 115
# LOOP: 373 / 10000 --> Max fitness: 115
# LOOP: 374 / 10000 --> Max fitness: 115
# LOOP: 375 / 10000 --> Max fitness: 117
# LOOP: 376 / 10000 --> Max fitness: 115
# LOOP: 377 / 10000 --> Max fitness: 116
# LOOP: 378 / 10000 --> Max fitness: 117
# LOOP: 379 / 10000 --> Max fitness: 115
# LOOP: 380 / 10000 --> Max fitness: 115
# LOOP: 381 / 10000 --> Max fitness: 115
# LOOP: 382 / 10000 --> Max fitness: 116
# LOOP: 383 / 10000 --> Max fitness: 115
# LOOP: 384 / 10000 --> Max fitness: 115
# LOOP: 385 / 10000 --> Max fitness: 116
# LOOP: 386 / 10000 --> Max fitness: 116
# LOOP: 387 / 10000 --> Max fitness: 117
# LOOP: 388 / 10000 --> Max fitness: 115
# LOOP: 389 / 10000 --> Max fitness: 114
# LOOP: 390 / 10000 --> Max fitness: 115
# LOOP: 391 / 10000 --> Max fitness: 115
# LOOP: 392 / 10000 --> Max fitness: 116
# LOOP: 393 / 10000 --> Max fitness: 115
# LOOP: 394 / 10000 --> Max fitness: 115
# LOOP: 395 / 10000 --> Max fitness: 119
# LOOP: 396 / 10000 --> Max fitness: 118
# LOOP: 397 / 10000 --> Max fitness: 116
# LOOP: 398 / 10000 --> Max fitness: 116
# LOOP: 399 / 10000 --> Max fitness: 116
# LOOP: 400 / 10000 --> Max fitness: 114
# LOOP: 401 / 10000 --> Max fitness: 116
# LOOP: 402 / 10000 --> Max fitness: 117
# LOOP: 403 / 10000 --> Max fitness: 115
# LOOP: 404 / 10000 --> Max fitness: 114
# LOOP: 405 / 10000 --> Max fitness: 116
# LOOP: 406 / 10000 --> Max fitness: 118
# LOOP: 407 / 10000 --> Max fitness: 116
# LOOP: 408 / 10000 --> Max fitness: 114
# LOOP: 409 / 10000 --> Max fitness: 114
# LOOP: 410 / 10000 --> Max fitness: 114
# LOOP: 411 / 10000 --> Max fitness: 115
# LOOP: 412 / 10000 --> Max fitness: 115
# LOOP: 413 / 10000 --> Max fitness: 116
# LOOP: 414 / 10000 --> Max fitness: 116
# LOOP: 415 / 10000 --> Max fitness: 114
# LOOP: 416 / 10000 --> Max fitness: 115
# LOOP: 417 / 10000 --> Max fitness: 117
# LOOP: 418 / 10000 --> Max fitness: 116
# LOOP: 419 / 10000 --> Max fitness: 114
# LOOP: 420 / 10000 --> Max fitness: 114
# LOOP: 421 / 10000 --> Max fitness: 116
# LOOP: 422 / 10000 --> Max fitness: 116
# LOOP: 423 / 10000 --> Max fitness: 115
# LOOP: 424 / 10000 --> Max fitness: 114
# LOOP: 425 / 10000 --> Max fitness: 115
# LOOP: 426 / 10000 --> Max fitness: 116
# LOOP: 427 / 10000 --> Max fitness: 115
# LOOP: 428 / 10000 --> Max fitness: 115
# LOOP: 429 / 10000 --> Max fitness: 115
# LOOP: 430 / 10000 --> Max fitness: 116
# LOOP: 431 / 10000 --> Max fitness: 116
# LOOP: 432 / 10000 --> Max fitness: 115
# LOOP: 433 / 10000 --> Max fitness: 118
# LOOP: 434 / 10000 --> Max fitness: 115
# LOOP: 435 / 10000 --> Max fitness: 115
# LOOP: 436 / 10000 --> Max fitness: 115
# LOOP: 437 / 10000 --> Max fitness: 116
# LOOP: 438 / 10000 --> Max fitness: 116
# LOOP: 439 / 10000 --> Max fitness: 114
# LOOP: 440 / 10000 --> Max fitness: 115
# LOOP: 441 / 10000 --> Max fitness: 116
# LOOP: 442 / 10000 --> Max fitness: 116
# LOOP: 443 / 10000 --> Max fitness: 116
# LOOP: 444 / 10000 --> Max fitness: 115
# LOOP: 445 / 10000 --> Max fitness: 115
# LOOP: 446 / 10000 --> Max fitness: 116
# LOOP: 447 / 10000 --> Max fitness: 116
# LOOP: 448 / 10000 --> Max fitness: 114
# LOOP: 449 / 10000 --> Max fitness: 115
# LOOP: 450 / 10000 --> Max fitness: 116
# LOOP: 451 / 10000 --> Max fitness: 115
# LOOP: 452 / 10000 --> Max fitness: 116
# LOOP: 453 / 10000 --> Max fitness: 117
# LOOP: 454 / 10000 --> Max fitness: 115
# LOOP: 455 / 10000 --> Max fitness: 114
# LOOP: 456 / 10000 --> Max fitness: 115
# LOOP: 457 / 10000 --> Max fitness: 116
# LOOP: 458 / 10000 --> Max fitness: 115
# LOOP: 459 / 10000 --> Max fitness: 115
# LOOP: 460 / 10000 --> Max fitness: 116
# LOOP: 461 / 10000 --> Max fitness: 114
# LOOP: 462 / 10000 --> Max fitness: 114
# LOOP: 463 / 10000 --> Max fitness: 115
# LOOP: 464 / 10000 --> Max fitness: 119
# LOOP: 465 / 10000 --> Max fitness: 114
# LOOP: 466 / 10000 --> Max fitness: 114
# LOOP: 467 / 10000 --> Max fitness: 114
# LOOP: 468 / 10000 --> Max fitness: 116
# LOOP: 469 / 10000 --> Max fitness: 116
# LOOP: 470 / 10000 --> Max fitness: 114
# LOOP: 471 / 10000 --> Max fitness: 116
# LOOP: 472 / 10000 --> Max fitness: 116
# LOOP: 473 / 10000 --> Max fitness: 116
# LOOP: 474 / 10000 --> Max fitness: 115
# LOOP: 475 / 10000 --> Max fitness: 115
# LOOP: 476 / 10000 --> Max fitness: 115
# LOOP: 477 / 10000 --> Max fitness: 115
# LOOP: 478 / 10000 --> Max fitness: 115
# LOOP: 479 / 10000 --> Max fitness: 116
# LOOP: 480 / 10000 --> Max fitness: 116
# LOOP: 481 / 10000 --> Max fitness: 116
# LOOP: 482 / 10000 --> Max fitness: 114
# LOOP: 483 / 10000 --> Max fitness: 115
# LOOP: 484 / 10000 --> Max fitness: 115
# LOOP: 485 / 10000 --> Max fitness: 115
# LOOP: 486 / 10000 --> Max fitness: 114
# LOOP: 487 / 10000 --> Max fitness: 115
# LOOP: 488 / 10000 --> Max fitness: 116
# LOOP: 489 / 10000 --> Max fitness: 115
# LOOP: 490 / 10000 --> Max fitness: 114
# LOOP: 491 / 10000 --> Max fitness: 115
# LOOP: 492 / 10000 --> Max fitness: 115
# LOOP: 493 / 10000 --> Max fitness: 115
# LOOP: 494 / 10000 --> Max fitness: 115
# LOOP: 495 / 10000 --> Max fitness: 116
# LOOP: 496 / 10000 --> Max fitness: 115
# LOOP: 497 / 10000 --> Max fitness: 116
# LOOP: 498 / 10000 --> Max fitness: 115
# LOOP: 499 / 10000 --> Max fitness: 116
# LOOP: 500 / 10000 --> Max fitness: 115
# LOOP: 501 / 10000 --> Max fitness: 114
# LOOP: 502 / 10000 --> Max fitness: 117
# LOOP: 503 / 10000 --> Max fitness: 115
# LOOP: 504 / 10000 --> Max fitness: 113
# LOOP: 505 / 10000 --> Max fitness: 114
# LOOP: 506 / 10000 --> Max fitness: 115
# LOOP: 507 / 10000 --> Max fitness: 118
# LOOP: 508 / 10000 --> Max fitness: 115
# LOOP: 509 / 10000 --> Max fitness: 116
# LOOP: 510 / 10000 --> Max fitness: 115
# LOOP: 511 / 10000 --> Max fitness: 118
# LOOP: 512 / 10000 --> Max fitness: 117
# LOOP: 513 / 10000 --> Max fitness: 115
# LOOP: 514 / 10000 --> Max fitness: 116
# LOOP: 515 / 10000 --> Max fitness: 115
# LOOP: 516 / 10000 --> Max fitness: 116
# LOOP: 517 / 10000 --> Max fitness: 115
# LOOP: 518 / 10000 --> Max fitness: 116
# LOOP: 519 / 10000 --> Max fitness: 116
# LOOP: 520 / 10000 --> Max fitness: 116
# LOOP: 521 / 10000 --> Max fitness: 118
# LOOP: 522 / 10000 --> Max fitness: 115
# LOOP: 523 / 10000 --> Max fitness: 115
# LOOP: 524 / 10000 --> Max fitness: 116
# LOOP: 525 / 10000 --> Max fitness: 116
# LOOP: 526 / 10000 --> Max fitness: 115
# LOOP: 527 / 10000 --> Max fitness: 115
# LOOP: 528 / 10000 --> Max fitness: 116
# LOOP: 529 / 10000 --> Max fitness: 115
# LOOP: 530 / 10000 --> Max fitness: 116
# LOOP: 531 / 10000 --> Max fitness: 115
# LOOP: 532 / 10000 --> Max fitness: 115
# LOOP: 533 / 10000 --> Max fitness: 115
# LOOP: 534 / 10000 --> Max fitness: 116
# LOOP: 535 / 10000 --> Max fitness: 115
# LOOP: 536 / 10000 --> Max fitness: 115
# LOOP: 537 / 10000 --> Max fitness: 120
#
# 🟢🟢🟢 SOLUTION FOUND at loop 537 / 10000
#
#
# State                                                             Length          Fitness Score
# ====================================================================================================
# [5, 1, 6, 14, 10, 8, 4, 15, 3, 0, 2, 12, 9, 7, 13, 11]              16                 120
# Time taken to find the solution: 8.41 seconds
